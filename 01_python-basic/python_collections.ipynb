# %% [markdown]
# # Lab 6: Ajou Library

# %% [markdown]
# ## Overview
#
# 이 실습의 목표는 표준 라이브러리의 도구에 익숙해지는 것입니다.<br/> 표준 라이브러리의 공통 유틸리티에 대한 연습을 하고 필요할 경우에 대비하여 나머지 도구에 대해 알아두시기 바랍니다.

# %% [markdown]
# ## Read
#
# 표준 라이브러리는 다음과 같습니다.
#
# ### [Take Me To The Standard Library](https://docs.python.org/3/library/)
#
# - Built-in [Functions](https://docs.python.org/3/library/functions.html), [Constants](https://docs.python.org/3/library/constants.html), [Types](https://docs.python.org/3/library/stdtypes.html), and [Exceptions](https://docs.python.org/3/library/exceptions.html)
# - [Text Processing Services](https://docs.python.org/3/library/text.html)
# - [Binary Data Services](https://docs.python.org/3/library/binary.html)
# - [Data Types](https://docs.python.org/3/library/datatypes.html)
# - [Numeric and Mathematical Modules](https://docs.python.org/3/library/numeric.html)
# - [Functional Programming Modules](https://docs.python.org/3/library/functional.html)
# - [File and Directory Access](https://docs.python.org/3/library/filesys.html)
# - [Data Persistence](https://docs.python.org/3/library/persistence.html)
# - [Data Compression and Archiving](https://docs.python.org/3/library/archiving.html)
# - [File Formats](https://docs.python.org/3/library/fileformats.html)
# - [Cryptographic Services](https://docs.python.org/3/library/crypto.html)
# - [Generic Operating System Services](https://docs.python.org/3/library/allos.html)
# - [Concurrent Execution](https://docs.python.org/3/library/concurrency.html)
# - [Context Variables](https://docs.python.org/3/library/contextvars.html)
# - [Networking and Interprocess Communication](https://docs.python.org/3/library/ipc.html)
# - [Internet Data Handling](https://docs.python.org/3/library/netdata.html)
# - [Structured Markup Processing Tools](https://docs.python.org/3/library/markup.html)
# - [Internet Protocols and Support](https://docs.python.org/3/library/internet.html)
# - [Multimedia Services](https://docs.python.org/3/library/mm.html)
# - [Internationalization](https://docs.python.org/3/library/i18n.html)
# - [Program Frameworks](https://docs.python.org/3/library/frameworks.html)
# - [Graphical User Interfaces with Tk](https://docs.python.org/3/library/tk.html)
# - [Development Tools](https://docs.python.org/3/library/development.html)
# - [Debugging and Profiling](https://docs.python.org/3/library/debug.html)
# - [Software Packaging and Distribution](https://docs.python.org/3/library/distribution.html)
# - [Python Runtime Services](https://docs.python.org/3/library/python.html)
# - [Custom Python Interpreters](https://docs.python.org/3/library/custominterp.html)
# - [Importing Modules](https://docs.python.org/3/library/modules.html)
# - [Python Language Services](https://docs.python.org/3/library/language.html)

# %% [markdown]
# ## Write
#
# 이 섹션에서는 Python 표준 라이브러리에서 보다 일반적인 모듈을 사용하는 방법을 연습합니다.

# %% [markdown]
# ##### Working with `collections.namedtuple`
#
#
# 이 섹션에서는 동물 무리 각각에 대한 메시지를 출력하는 코드를 수정합니다.
#
# 읽을 수 있는 속성 참조를 추가하기 위해 `collections.namedtuple`을 사용하여 다음 코드를 더 Pythonic하게 다시 작성하십시오.
#
# 이 동물의 속성은 `'name'`, `'species'`, `'color'`, and `'age'` 입니다.

# %%
import collections

lassie = ('Lassie', 'dog', 'black', 12)
buddy = ('Buddy', 'pupper', 'red', 0.5)
astro = ('Astro', 'doggo', 'grey', 15)
mrpb = ('Mr. Peanutbutter', 'dog', 'golden', 35)
bojack = ('BoJack Horseman', 'horse', 'brown', 52)
pc = ('Princess Carolyn', 'cat', 'pink', 34)
tinkles = ('Mr. Tinkles', 'cat', 'white', 7)
pupper = ('Bella', 'pupper', 'brown', 0.5)
doggo = ('Max', 'doggo', 'brown', 5)
seuss = ('The Cat in the Hat', 'cat', 'stripey', 27)
pluto = ('Pluto (Disney)', 'dog', 'orange', 3)
plu2o = ('Pluto (space)', 'planet', 'brownish', 4500000000)
yertle = ('Yertle', 'turtle', 'green', 130)
horton = ('Horton', 'elephant', 'blue', 79)

for animal in [lassie, buddy, astro, mrpb, bojack, pc, tinkles, pupper, doggo, seuss, pluto, plu2o, yertle, horton]:
    if animal[1] == 'dog' or animal[1] == 'doggo' or animal[1] == 'pupper':
        if animal[3] > 5:
            print(animal[0] + ' is an old ' + animal[2] + ' ' + animal[1] + ' who is ' + str(animal[3]) + ' years old.')
        else:
            print(animal[0] + ' is a young ' + animal[2] + ' ' + animal[1] + ' who is ' + str(animal[3]) + ' years old.')
    else:
        print(animal[0] + ' is a ' + str(animal[3]) + '-year-old non-canine ' + animal[2] + ' ' + animal[1] + '.')
        
# Prints out:
# Lassie is an old black dog who is 12 years old.
# Buddy is a young red pupper who is 0.5 years old.
# Astro is an old grey doggo who is 15 years old.
# Mr. Peanutbutter is an old golden dog who is 35 years old.
# BoJack Horseman is a 52-year-old non-canine brown horse.
# Princess Carolyn is a 34-year-old non-canine pink cat.
# Mr. Tinkles is a 7-year-old non-canine white cat.
# Bella is a young brown pupper who is 0.5 years old.
# Max is a young brown doggo who is 5 years old.
# The Cat in the Hat is a 27-year-old non-canine stripey cat.
# Pluto (Disney) is a young orange dog who is 3 years old.
# Pluto (space) is a 4500000000-year-old non-canine brownish planet.
# Yertle is a 130-year-old non-canine green turtle.
# Horton is a 79-year-old non-canine blue elephant.

# 다음을 출력합니다:
# 래시는 12살의 늙은 검은 개입니다.
# 버디는 0.5세의 어린 빨간 강아지입니다.
# 아스트로는 15세의 늙은 회색 강아지입니다.
# 피넛버터 씨는 35세의 노령견입니다.
# 보잭 홀스맨은 52세의 개가 아닌 갈색 말입니다.
# 캐롤린 공주는 34세의 송곳니가 아닌 핑크색 고양이입니다.
# 팅클스 씨는 7살짜리 송곳니가 아닌 흰 고양이입니다.
# 벨라는 0.5세의 어린 갈색 강아지입니다.
# 맥스는 5살 어린 갈색 강아지입니다.
# 모자를 쓴 고양이는 27세의 개가 아닌 줄무늬 고양이입니다.
# 명왕성(디즈니)은 3살 어린 오렌지색 강아지입니다.
# 명왕성(우주)은 4500000000년 된 개가 아닌 갈색 행성입니다.
# Yertle은 130년 된 개가 아닌 녹색 거북이입니다.
# Horton은 79세의 개가 아닌 푸른 코끼리입니다.
# Out:
# Lassie is an old black dog who is 12 years old.
# Buddy is a young red pupper who is 0.5 years old.
# Astro is an old grey doggo who is 15 years old.
# Mr. Peanutbutter is an old golden dog who is 35 years old.
# BoJack Horseman is a 52-year-old non-canine brown horse.
# Princess Carolyn is a 34-year-old non-canine pink cat.
# Mr. Tinkles is a 7-year-old non-canine white cat.
# Bella is a young brown pupper who is 0.5 years old.
# Max is a young brown doggo who is 5 years old.
# The Cat in the Hat is a 27-year-old non-canine stripey cat.
# Pluto (Disney) is a young orange dog who is 3 years old.
# Pluto (space) is a 4500000000-year-old non-canine brownish planet.
# Yertle is a 130-year-old non-canine green turtle.
# Horton is a 79-year-old non-canine blue elephant.

# %% [markdown]
# #### Using `collections.defaultdict` and `collections.Counter`
#
# 아래 내용을 데이터 소스로 사용하는 경우 영어에서 가장 일반적인 세 가지 단어 길이는 무엇일까요?
#
# `/usr/share/dict/words` (Window, `https://stanfordpython.com/res/misc/words`)

# %%
# 단어 목록의 사본을 다운로드했다면 다른 파일 위치로 변경하십시오.
# 이 파일에는 한 줄에 한 단어가 있음을 기억하십시오.
FILENAME = '/usr/share/dict/words'

# 영어에서 가장 일반적인 세 단어 길이를 인쇄합니다.

# %% [markdown]
# ##### Evil Hangman Redux (optional)
#
#
# 문자가 `letter`와 다른 경우 `word`의 각 문자를 대시로 대체하는 `mask(word, letter)` 함수가 제공된다고 가정합니다.
#
# 예를 들어, `mask('banana', 'a')  # => '-a-a-a'`.
#
# 단어의 소스 모음과 선택한 문자가 주어지면 마스크를 공유하는 상위 `num_families` 단어 모음을 반환합니다.
#
# 특히, 선택된 문자가 주어지면 단어 패밀리는 모든 단어가 해당 문자와 함께 적용될 때 동일한 마스크를 생성하는 단어 패밀리입니다.
#
#
# 예를 들어, 선택한 문자가 `'s'`이면 `'sees'`와 `'says'`는 같은 계열(`'s--s'`)에 속하지만 `'sass'` 다른 가족(`'s-ss'`)에 있을 것입니다.

# %%
import collections

def mask(word, letter):
    return ''.join('-' if letter != ch else letter for ch in word)


def largest_families(words, letter, num_families=3):
    pass


# Quick test
words = ['sees', 'says', 'sass']
print(largest_families(words, 's', num_families=1)[0])  # => Should print ['sees', 'says']

# %% [markdown]
# #### Wordplay
#
#
# `/usr/share/dict/words`에 있는 단어 목록을 사용하거나 Windows를 실행하는 경우
# `http://stanfordpython.com/res/misc/words`에 있는 단어 목록을 사용하여 5개의 모음이 있는 모든 단어를 결정합니다.
#
# 'a'', ''e'', ''i'', ''o'', ''u''를 순서대로 포함하고 임의의 수(0 포함)의 단어 문자를 포함하는 단어 'a' 앞, 모음 사이, 'u' 뒤.

# %%
import re

# Change me to another file location if you've downloaded a copy of the word list.
# Recall that this file has one word per line.
FILENAME = '/usr/share/dict/words'
pattern = re.compile('your-regular-expression-here')

# TODO(you): Print out any words that have five vowels in order.

# %% [markdown]
# #### Regex Crossword Checker
#
# Regex Crossword 링크
#
# [Regex Crossword](https://regexcrossword.com/)
#
# 임의의 정규식 십자말 풀이를 검사하는 함수를 작성하십시오. 함수는 두 개의 목록을 가져와야 합니다. 하나는 가로 단서를 나타내고 다른 하나는 세로 단서를 나타냅니다.
# 또한 행 우선 순위의 목록 목록 형식으로 십자말 풀이에 대한 잠재적인 솔루션을 가져와야 합니다 (즉, 요소는 행을 나타내는 목록입니다. 잠재적 솔루션이 실제로 유효한지 여부를 반환합니다.
#
# ```Python
# def regex_crossword_check(horizontal_patterns, vertical_patterns, candidate):
#     pass  # Your implementation here
# ```
#
# 예를 들어, 첫 번째 "초보자" 퍼즐("비틀즈"라고 함)에 해당하는 호출은 다음과 같습니다.
#
#
# ```Python
# horiz = [r'HE|LL|O+', r'[PLEASE]+']
# vert = [r'[^SPEAK]+', r'EP|IP|EF']
# candidate = [
#     ['H', 'E'],
#     ['L', 'P']
# ]
# regex_crossword_check(horiz, vert, candidate)  # => True
# ```
#
# 두 번째 "Experiences" 퍼즐("Royal Dinner"라고 함)에 해당하는 호출은 다음과 같습니다.
#
# ```Python
# horiz = [r'(Y|F)(.)\2[DAF]\1', r'(U|O|I)*T[FRO]+', r'[KANE]*[GIN]*']
# vert = [r'(FI|A)+', r'(YE|OT)K', r'(.)[IF]+', r'[NODE]+', r'(FY|F|RG)+']
# candidate = [
#     ['F', 'O', 'O', 'D', 'F'],
#     ['I', 'T', 'F', 'O', 'R'],
#     ['A', 'K', 'I', 'N', 'G']
# ]
# regex_crossword_check(horiz, vert, candidate)  # => True
# ```
#
# * `re.match`나 `re.search` 대신 `re.fullmatch`를 사용할 수도 있습니다. 전자는 전체 문자열에 대해 패턴 문자열을 일치시키는 반면, 후자는 접두사 문자열이나 하위 문자열이 각각 패턴과 일치하는지 확인합니다.
# * 가로 세로 단서 목록의 길이에서 십자말 풀이의 너비와 높이를 각각 얻을 수 있습니다.
# * `zip` 을 이용할 수도 있습니다.

# %%
import re
import string


def regex_crossword_check(horizontal_patterns, vertical_patterns, candidate):
    pass  # Your implementation 


# Quick tests.
horiz = [r'HE|LL|O+', r'[PLEASE]+']
vert = [r'[^SPEAK]+', r'EP|IP|EF']
candidate = [
    ['H', 'E'],
    ['L', 'P']
]
print(regex_crossword_check(horiz, vert, candidate))  # => True


horiz = [r'(Y|F)(.)\2[DAF]\1', r'(U|O|I)*T[FRO]+', r'[KANE]*[GIN]*']
vert = [r'(FI|A)+', r'(YE|OT)K', r'(.)[IF]+', r'[NODE]+', r'(FY|F|RG)+']
candidate = [
    ['F', 'O', 'O', 'D', 'F'],
    ['I', 'T', 'F', 'O', 'R'],
    ['A', 'K', 'I', 'N', 'G']
]
print(regex_crossword_check(horiz, vert, candidate))  # => True

# %% [markdown]
# #### Regex Crossword Solver (challenge)
#
#
# 임의의 정규식 십자말 풀이를 푸는 함수를 작성하십시오.
#
# 함수는 두 개의 목록을 가져와야 합니다. 하나는 가로 단서, 다른 하나는 세로 단서, 십자말 풀이의 너비와 높이를 나타내는 정수 두 개, 그리고 가능한 알파벳을 나타내는 키워드 인수입니다. 행 우선 순서로 읽은 문자를 반환합니다.
#
# ```Python
# import re
# import string
# def regex_crossword_solve(horizontal_patterns, vertical_patterns, alphabet=string.ascii_uppercase):
#     pass
# ```
#
# 예를 들어, 첫 번째 "초보자" 퍼즐("비틀즈"라고 함)에 해당하는 호출은 다음과 같습니다.
#
# ```Python
# horiz = [r'HE|LL|O+', r'[PLEASE]+']
# vert = [r'[^SPEAK]+', r'EP|IP|EF']
# regex_crossword_solve(horiz, vert)
# ```
#
# (이 경우 고유한) 솔루션 `[['H', 'E'], ['L', 'P']]`에서 파생된 최종 답변 `['HELP']`을 반환합니다. 답변이 여러 개인 경우 모두 반환하십시오.

# %%
def regex_crossword_solver(horiz, vert):
  pass

def test_regex_crossword_solve():
  pass

# %%
horiz = [r'.*M?O.*', r'(AN|FE|BE)']
vert = [r'(A|B|C)\1', r'(AB|OE|SK)']

# %%
horiz = [r'.*M?O.*', r'(AN|FE|BE)']
vert = [r'(A|B|C)\1', r'(AB|OE|SK)']

# %% [markdown]
# #### Tabulation
#
# 계산 룩업 테이블을 생성하는 `tabulate` 함수를 작성하십시오. `tabulate`는 함수, 시작 번호(기본값 0), 단계 크기(기본값 1)의 세 가지 인수를 취해야 합니다.
#
# ```Python
# def tabulate(f, start=0, step=1):
#     pass
# ```
#
# This function can be used as follows:
#
# ```Python
# sqgen = tabulate(lambda x: x ** 2)
# next(sqgen)  # => 0 (which is equal to f(0))
# next(sqgen)  # => 1 (which is equal to f(1))
# next(sqgen)  # => 4 (which is equal to f(2))
# next(sqgen)  # => 9 (which is equal to f(3))
# ```
# 구현은 1행 43자입니다.
#
# 힌트: `itertools.count` 함수를 확인해보세요.

# %%
import itertools


def tabulate(f, start=0, step=1):
    pass


sqgen = tabulate(lambda x: x ** 2)
print(next(sqgen))  # => 0 (which is equal to f(0))
print(next(sqgen))  # => 1 (which is equal to f(1))
print(next(sqgen))  # => 4 (which is equal to f(2))
print(next(sqgen))  # => 9 (which is equal to f(3))

# %% [markdown]
# ### JSON

# %%
import json

JSON_FILE = 'my-downloaded-file.json'  # Rename me after downloading a file.

# Load the JSON file into a Python data structure.

# Process something about the data.

# %% [markdown]
# ### `random`

# %% [markdown]
# ### Using `sys` for command-line tools.

# %% [markdown]
# #### Addition
#
#
# 더하고 싶은 숫자를 나타내는 추가 인수의 수와 함께 명령줄에서 실행할 수 있는 Python 스크립트 `add.py`를 작성하십시오. 스크립트는 합계를 인쇄해야 합니다! 부동 소수점으로 변환할 수 없는 인수가 있으면 무시하십시오.
# 스크립트에 추가 인수가 없으면 오류 메시지를 인쇄하고 종료해야 합니다.
#
# `sys.argv`를 사용하여 명령줄 인수에 접근할 수 있습니다.
#
# 다음과 같이 명령줄에서 스크립트를 호출할 수 있어야 합니다.
#
# ```
# (cs41-env)$ python add.py 4 1
# 5.0
# (cs41-env)$ python add.py 17 38 "Hey wassup" "hello"
# 55.0
# (cs41-env)$ python add.py 8 6 7 5 3 0 9
# 38.0
# (cs41-env)$ python add.py
# Usage: python add.py <nums>
#
#     Add some numbers together
# ```
#
# ##### Argument Parsing with `argparse`
#
# Python의 argparse 모듈은 명령줄 인수를 허용하는 스크립트를 정의하는 더 좋은 방법을 제공합니다. argparse 문서를 읽고 argparse에서 제공하는 도구를 사용하여 위의 프로그램을 다시 작성하십시오.

# %% [markdown]
# #### `tree` (challenge)
#
#
# 명령줄 유틸리티 `tree`를 에뮬레이트하는 프로그램을 작성하세요. 이 유틸리티는 인수 이름을 기반으로 하는 디렉토리 구조를 인쇄합니다. 인수가 없으면 현재 작업 디렉토리를 사용합니다.
#
# 예를 들어,
#
# ```
# $ python3 tree.py python-labs/
# python-labs/
# ├── LICENSE
# ├── NOTES.md
# ├── README.md
# ├── markdown
# │   ├── lab1-warmup.md
# │   ├── lab2-datastructures.md
# │   ├── lab3-functions.md
# │   ├── lab4-fp.md
# │   ├── lab5-oop.md
# │   ├── lab6-standardlibrary.md
# │   ├── lab7-thirdparty.md
# │   └── lab8-pythonecosystem.md
# └── notebooks
#     ├── lab1-warmup-notebook.ipynb
#     ├── lab2-datastructures-notebook.ipynb
#     ├── lab3-functions-notebook.ipynb
#     ├── lab4-fp-notebook.ipynb
#     ├── lab5-oop-notebook.ipynb
#     ├── lab6-standardibrary-notebook.ipynb
#     ├── lab7-thirdparty-notebook.ipynb
#     └── lab8-pythonecosystem-notebook.ipynb
# ```
#
# 위의 내용은 예시입니다.
# 실제 `python-labs/` 디렉토리가 다음과 같지 않아도 됩니다.

# %% [markdown]
# #### Improving `tree` (super challenge)
#
#
# 위의 매뉴얼 페이지에 나열된 사용 사례를 처리하도록 `tree` 프로그램을 업데이트하십시오. 심볼릭 링크, 최대 깊이 재귀 또는 패턴 일치를 처리할 수 있을까요?

# %% [markdown]
# ### All Together Now
#
#
# 이 마지막 문제는 지금까지 본 모든 모듈을 통합합니다. 우리는 두 공항 사이의 가장 짧은 공항 여행을 결정하는 도구를 만듭니다.

# %% [markdown]
# #### Airport Data
# 먼저 데이터를 살펴보겠습니다. OpenFlights는 다음 데이터 파일을 게시합니다.
#
# * [Airlines](https://raw.githubusercontent.com/jpatokal/openflights/master/data/airlines.dat)
# * [Airports](https://raw.githubusercontent.com/jpatokal/openflights/master/data/airports.dat)
# * [Routes](https://raw.githubusercontent.com/jpatokal/openflights/master/data/routes.dat)
#
#
# 데이터에 대한 정보는 아래 링크를 참고하세요.
#
# [DataHub](https://datahub.io/dataset/open-flights)
#
# [by OpenFlights itself](https://openflights.org/data.html)

# %% [markdown]
# 두 개의 공항 코드(SFO 및 JFK와 같은)와 최대 구간 수가 주어지면 출발지 공항에서 목적지 공항까지 최대한 많은 구간으로 이동하는 모든 가능한 방법을 인쇄하는 스크립트를 작성합니다.
#
# ```
# $ python3 flights.py SFO JFK 2
# SFO -> JFK
# SFO -> LAX -> JFK
# SFO -> ORD -> JFK
# SFO -> DFW -> JFK
# ...
# SFO -> PDX -> JFK
# ```
#
#
# 이 스크립트를 얼마나 강력하게 만들 수 있습니까? 여기에서 본 모든 표준 라이브러리 모듈을 활용하는 추가 기능을 추가해보세요.

# %% [markdown]
# ### Cute Modules

# %% [markdown]
# #### `turtle` - Turtle graphics
#
#
# 다음 코드를 실행하면, Turtle을 보여주는 그래픽 창이 나타납니다.

# %%
# !pip install ColabTurtle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ColabTurtle
#   Downloading ColabTurtle-2.1.0.tar.gz (6.8 kB)
# Building wheels for collected packages: ColabTurtle
#   Building wheel for ColabTurtle (setup.py) ... done
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7657 sha256=42aff8f577d2877d5be76ac505040fa61b93e772c6665b517daea9845448a855
#   Stored in directory: /root/.cache/pip/wheels/0d/ab/65/cc4478508751448dfb4ecb20a6533082855c227dfce8c13902
# Successfully built ColabTurtle
# Installing collected packages: ColabTurtle
# Successfully installed ColabTurtle-2.1.0

# %%
from ColabTurtle.Turtle import *
initializeTurtle()

side_length = 100
angle = 360/4


for i in range(4):
  forward(side_length)
  right(angle)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="150.0" x2="500.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="500.0" y1="150.0" x2="500.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="500.0" y1="250.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360.0,400.0,250.0) translate(382.0, 232.0)">
# <path style=" stroke:none;fill-rule:evenodd;fill:white;fill-opacity:1;" d="M 18.214844 0.632812 C 16.109375 1.800781 15.011719 4.074219 15.074219 7.132812 L 15.085938 7.652344 L 14.785156 7.496094 C 13.476562 6.824219 11.957031 6.671875 10.40625 7.066406 C 8.46875 7.550781 6.515625 9.15625 4.394531 11.992188 C 3.0625 13.777344 2.679688 14.636719 3.042969 15.027344 L 3.15625 15.152344 L 3.519531 15.152344 C 4.238281 15.152344 4.828125 14.886719 8.1875 13.039062 C 9.386719 12.378906 10.371094 11.839844 10.378906 11.839844 C 10.386719 11.839844 10.355469 11.929688 10.304688 12.035156 C 9.832031 13.09375 9.257812 14.820312 8.96875 16.078125 C 7.914062 20.652344 8.617188 24.53125 11.070312 27.660156 C 11.351562 28.015625 11.363281 27.914062 10.972656 28.382812 C 8.925781 30.84375 7.945312 33.28125 8.238281 35.1875 C 8.289062 35.527344 8.28125 35.523438 8.917969 35.523438 C 10.941406 35.523438 13.074219 34.207031 15.136719 31.6875 C 15.359375 31.417969 15.328125 31.425781 15.5625 31.574219 C 16.292969 32.042969 18.023438 32.964844 18.175781 32.964844 C 18.335938 32.964844 19.941406 32.210938 20.828125 31.71875 C 20.996094 31.625 21.136719 31.554688 21.136719 31.558594 C 21.203125 31.664062 21.898438 32.414062 22.222656 32.730469 C 23.835938 34.300781 25.5625 35.132812 27.582031 35.300781 C 27.90625 35.328125 27.9375 35.308594 28.007812 34.984375 C 28.382812 33.242188 27.625 30.925781 25.863281 28.425781 L 25.542969 27.96875 L 25.699219 27.785156 C 28.945312 23.960938 29.132812 18.699219 26.257812 11.96875 L 26.207031 11.84375 L 27.945312 12.703125 C 31.53125 14.476562 32.316406 14.800781 33.03125 14.800781 C 33.976562 14.800781 33.78125 13.9375 32.472656 12.292969 C 28.519531 7.355469 25.394531 5.925781 21.921875 7.472656 L 21.558594 7.636719 L 21.578125 7.542969 C 21.699219 6.992188 21.761719 5.742188 21.699219 5.164062 C 21.496094 3.296875 20.664062 1.964844 19.003906 0.855469 C 18.480469 0.503906 18.457031 0.5 18.214844 0.632812"/>
# </g>
#       </svg>

# %%
"""import turtle

turtle.left(180)
turtle.forward(200)
turtle.left(180)

turtle.color('red', 'yellow')
turtle.begin_fill()

for _ in range(36):
    turtle.forward(400)
    turtle.left(170)
    if abs(turtle.pos()) < 1:
        break

turtle.end_fill()
turtle.done()"""

# %% [markdown]
# #### `unicodedata` - Unicode Database

# %%
import unicodedata

print(unicodedata.lookup('SLICE OF PIZZA'))  # => '🍕'

print(unicodedata.name('👌'))  # => 'OK HAND SIGN'
# Out:
# 🍕
# OK HAND SIGN

# %% [markdown]
# #### `this` and `antigravity`

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
import antigravity

# %% [markdown]
# > With <3 by @sredmond
