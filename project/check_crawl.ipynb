# %%
import requests
import bs4
sub_url = "https://product.kyobobook.co.kr/detail/" + "S000061532442"
data = requests.get(sub_url).content
soup = bs4.BeautifulSoup(data, "lxml")
print(
    soup.find("table",class_="tbl_row").tbody.get_text()\
    .strip().replace(" ","").split("\n")[5].replace("쪽","")
)
    # .replace("\n","")\
    # .replace("\t",""))
# Out:
# 308

# %%
import pandas as pd

kor_book = pd.DataFrame(columns=[
    "title", "genre_list", "author", "rating", "publisher",
    "p_date", "description", "pages", "imgUrl"
])
print(kor_book)
# Out:
# Empty DataFrame
# Columns: [title, genre_dic, author, rating, publisher, p_date, description, pages, imgUrl]
# Index: []

# %%
import json
url = "https://product.kyobobook.co.kr/api/gw/pdt/category/all?page=2&per=20&saleCmdtDvsnCode=KOR&saleCmdtClstCode=0101&sort=new"
url = "https://product.kyobobook.co.kr/api/gw/pdt/category/all?page=1&per=50&saleCmdtDvsnCode=KOR&saleCmdtClstCode=0101&sort=sel"
data = requests.get(url).content
data = json.loads(data.decode("utf-8"))
print(data["data"]["tabContents"][0]["inbukCntt"])
# with open("content.json", "w", encoding="utf-8") as f:
#     json.dump(data,f, indent="\t", ensure_ascii=False)

# img_src_url = "https://contents.kyobobook.co.kr/sih/fit-in/142x0/pdt/"
# imgUrl = img_src_url + data["data"]["tabContents"][0]["cmdtcode"] + ".jpg"
# data = requests.get(imgUrl).content
# with open("test.jpg", "wb") as f:
#     f.write(data)
# Out:
# ‘우리 시대 최고의 문장가’ ‘작가들의 작가’로 일컬어지는 소설가 김훈의 신작 장편소설 『하얼빈』이 출간되었다. 『하얼빈』은 김훈이 작가로 활동하는 내내 인생 과업으로 삼아왔던 특별한 작품이다. 작가는 청년 시절부터 안중근의 짧고 강렬했던 생애를 소설로 쓰려는 구상을 품고 있었고, 안중근의 움직임이 뿜어내는 에너지를 글로 감당하기 위해 오랜 시간을 들여 ‘인간 안중근’을 깊이 이해해나갔다. 그리고 2022년 여름, 치열하고 절박한 집필 끝에 드디어 그 결과물을 세상에 내놓게 되었다.
#
#  『하얼빈』에서는 단순하게 요약되기 쉬운 실존 인물의 삶을 역사적 기록보다도 철저한 상상으로 탄탄하게 재구성하는 김훈의 글쓰기 방식이 빛을 발한다. 이러한 서사는 자연스럽게 김훈의 대표작 『칼의 노래』를 떠올리게 하는데, 『칼의 노래』가 명장으로서 이룩한 업적에 가려졌던 이순신의 요동하는 내면을 묘사했다면 『하얼빈』은 안중근에게 드리워져 있던 영웅의 그늘을 걷어내고 그의 가장 뜨겁고 혼란스러웠을 시간을 현재에 되살려놓는다.
#
# 난세를 헤쳐가야 하는 운명을 마주한 미약한 인간의 내면에 집중하는 김훈의 시선은 『하얼빈』에서 더욱 깊이 있고 오묘한 장면들을 직조해낸다. 소설 안에서 이토 히로부미로 상징되는 제국주의의 물결과 안중근으로 상징되는 청년기의 순수한 열정이 부딪치고, 살인이라는 중죄에 임하는 한 인간의 대의와 윤리가 부딪치며, 안중근이 천주교인으로서 지닌 신앙심과 속세의 인간으로서 지닌 증오심이 부딪친다. 이토록 다양한 층위에서 벌어지는 복합적인 갈등을 날렵하게 다뤄내며 안중근이라는 인물을 바라보는 시야의 차원을 높이는 이 작품은 김훈의 새로운 대표작으로 소개되기에 모자람이 없다.

# %%
x ="['국내도서', '소설', '한국소설', '역사/대하소설', '장르소설', '역사소설']"
x = x.replace("[","").replace("]","").replace("\'","").replace(" ","")
print(x)
y = ['국내도서', '소설', '한국소설', '역사/대하소설', '장르소설', '역사소설']
print(str(y).replace("[","").replace("]","").replace("\'","").replace(" ",""))
# Out:
# 국내도서,소설,한국소설,역사/대하소설,장르소설,역사소설
# 국내도서,소설,한국소설,역사/대하소설,장르소설,역사소설

# %%
import sqlite3
conn = sqlite3.connect("KoreanBook.db")

cur = conn.cursor()

conn.execute('CREATE TABLE employee_data(id INTEGER, title TEXT, genres TEXT, author TEXT, rating REAL, publisher TEXT, pages INTEGER, description TEXT, imgUrl TEXT)')

cur.execute(
    f'INSERT INTO employee_data VALUES (?, ?, ?, ?, ?)'
)

conn.commit()
conn.close()

# %%
import pandas as pd
from IPython.display import display
df = pd.read_csv("./data/korean-books.csv")
# print(df.iloc[0])
display(df)
# Out:
#                           title                          genres author  \
# 0                           하얼빈  국내도서,소설,한국소설,역사/대하소설,장르소설,역사소설     김훈
# 1                     아버지의 해방일지             국내도서,소설,한국소설,한국소설일반    정지아
# 2                     불편한 편의점 2             국내도서,소설,한국소설,한국소설일반    김호연
# 3       불편한 편의점(40만부 기념 벚꽃 에디션)             국내도서,소설,한국소설,한국소설일반    김호연
# 4                 작별인사(밤하늘 에디션)             국내도서,소설,한국소설,한국소설일반    김영하
# 5  어서 오세요, 휴남동 서점입니다 (여름 숲 에디션)             국내도서,소설,한국소설,한국소설일반    황보름
#
#    rating publisher    p-date  pages  \
# 0    9.75      문학동네  20220803    308
# 1    9.92        창비  20220902    268
# 2    9.70     나무옆의자  20220810    320
# 3    9.81     나무옆의자  20210420    268
# 4    9.48      복복서가  20220502    308
# 5    9.69    클레이하우스  20220117    364
#
#                                          description  \
# 0  ‘우리 시대 최고의 문장가’ ‘작가들의 작가’로 일컬어지는 소설가 김훈의 신작 장편...
# 1  김유정문학상 심훈문학대상 이효석문학상 등을 수상하며 문학성을 두루 입증받은 ‘리얼리...
# 2  출간 후 1년이 넘도록 독자의 사랑을 받으며 베스트셀러 상위권을 지키고 있는 소설,...
# 3  누적 판매 40만부 돌파, 2022년 가장 사랑받는 소설\n★★★전 서점 종합베스트...
# 4  『작별인사』 20만 부 돌파 기념 밤하늘 스페셜 에디션 출간!\n“김영하가 쓴 가장...
# 5  “책과 서점을 통해 새로운 관계를 만들고, 스스로 일어서기 위해 애쓰는 사람들의 이...
#
#                                               imgUrl
# 0  https://contents.kyobobook.co.kr/sih/fit-in/14...
# 1  https://contents.kyobobook.co.kr/sih/fit-in/14...
# 2  https://contents.kyobobook.co.kr/sih/fit-in/14...
# 3  https://contents.kyobobook.co.kr/sih/fit-in/14...
# 4  https://contents.kyobobook.co.kr/sih/fit-in/14...
# 5  https://contents.kyobobook.co.kr/sih/fit-in/14...

# %%
import bs4
import requests
import json
import pandas as pd
import warnings

warnings.filterwarnings(action="ignore")

kor_book = pd.DataFrame(columns=[
    "title", "genre_dic", "author", "rating", "publisher",
    "p_date", "description", "pages", "imgUrl"
])
print(kor_book)

subject_list = {
    "01":"소설", "03":"시/에세이", "05":"인문","13":"경제/경영", "15":"자기계발", 
    "19":"역사/문화", "21":"종교", "17":"정치/사회", "23":"예술/대중문화",
    "29":"과학", "26":"기술/공학", "33":"컴퓨터/IT",

    "38":"청소년", "11":"취미/실용/스포츠", "27":"외국어", "32":"여행",
    "07":"가정/육아", "08":"요리", "09":"건강"
}

img_src_url = "https://contents.kyobobook.co.kr/sih/fit-in/142x0/pdt/"
success = [200,299]
max_page = 11
print("="*100)

for i in subject_list:
    print("start ",subject_list[i])
    for j in range(1,50,2):
        subjectNum = int(i)*100 + j
        if i==38:
            max_page = 6
        for page in range(1,max_page):
            url = f"https://product.kyobobook.co.kr/api/gw/pdt/category/all?page={page}&per=50&saleCmdtDvsnCode=KOR&saleCmdtClstCode={subjectNum:04d}&sort=sel"
            data = requests.get(url)
            if success[0]<=data.status_code and data.status_code<=success[1]:
                data = json.loads(data.content.decode("utf-8"))
                for n in range(50):
                    book = data["data"]["tabContents"][n]
                    title = book["cmdtName"]
                    author = book["chrcName"]
                    publisher = book["pbcmName"]
                    rating = book["revwRvgrAvg"] if book["revwRvgrAvg"]!=0 else None
                    p_date = book["rlseDate"]
                    description = book["inbukCntt"]
                    imgUrl = img_src_url + book["cmdtcode"] + ".jpg"
                    sub_url = "https://product.kyobobook.co.kr/detail/" + book["saleCmdtId"]
                    sub_data = requests.get(sub_url).content
                    sub_soup = bs4.BeautifulSoup(sub_data, "lxml")
                    genre_dic = {}
                    for genres in (sub_soup.find_all("li",class_="category_list_item")):
                        for genre in genres.find_all("a"):
                            genre_dic[genre.get_text()] = 1
                    genre_list = list(genre_dic.keys())
                    try:
                        pages = sub_soup.find("table",class_="tbl_row").tbody.get_text()\
                            .strip().replace(" ","").split("\n")[5].replace("쪽","")
                        kor_book = kor_book.append({
                            "title":title,
                            "genre_list":genre_list,
                            "author":author,
                            "rating":rating,
                            "publisher":publisher,
                            "p_date":p_date,
                            "description":description,
                            "pages":pages,
                            "imgUrl":imgUrl,
                            },
                            ignore_index=True
                        )
                    except:
                        print(title,"ERROR")
                        pages = None
            else:
                pass
# Out:
# Empty DataFrame
# Columns: [title, genre_dic, author, rating, publisher, p_date, description, pages, imgUrl]
# Index: []
# ====================================================================================================
# start  소설
# 대표님의 아이 1~2 세트 ERROR
# 시맨틱 에러 세트 ERROR
# 본즈 앤 올 ERROR
# 늑대와 양피지 6 ERROR
# 살육에 이르는 병 ERROR
# 이합화타적백묘사존: 바보 허스키와 그의 흰 고양이 사존 세트(4-6권) ERROR
# 인사반파자구계통 일반판 박스 세트(상, 중, 하+소장박스) ERROR
# 마도조사 4 ERROR
# 이합화타적백묘사존:  바보 허스키와 그의 흰 고양이 사존 9 ERROR
# 사드 전집 2: 소돔 120일 혹은 방탕주의 학교 ERROR
# 사드 전집 2: 소돔 120일 혹은 방탕주의 학교 ERROR
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/ljj0512/private/workspace/data-mining/project/crawl-system.ipynb Cell 4 in <cell line: 29>()
#      <a href='vscode-notebook-cell://ssh-remote%2B202.30.30.19/home/ljj0512/private/workspace/data-mining/project/crawl-system.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=38'>39</a> data = json.loads(data.content.decode("utf-8"))
#      <a href='vscode-notebook-cell://ssh-remote%2B202.30.30.19/home/ljj0512/private/workspace/data-mining/project/crawl-system.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=39'>40</a> for n in range(50):
# ---> <a href='vscode-notebook-cell://ssh-remote%2B202.30.30.19/home/ljj0512/private/workspace/data-mining/project/crawl-system.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=40'>41</a>     book = data["data"]["tabContents"][n]
#      <a href='vscode-notebook-cell://ssh-remote%2B202.30.30.19/home/ljj0512/private/workspace/data-mining/project/crawl-system.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=41'>42</a>     title = book["cmdtName"]
#      <a href='vscode-notebook-cell://ssh-remote%2B202.30.30.19/home/ljj0512/private/workspace/data-mining/project/crawl-system.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=42'>43</a>     author = book["chrcName"]
#
# IndexError: list index out of range

# %%
print(len(kor_book))
print(kor_book.iloc[0:5])
# Out:
# 247
#                      title genre_dic author  rating publisher    p_date  \
# 0                      하얼빈       NaN     김훈    9.75      문학동네  20220803
# 1                아버지의 해방일지       NaN    정지아    9.92        창비  20220902
# 2                불편한 편의점 2       NaN    김호연    9.70     나무옆의자  20220810
# 3  불편한 편의점(40만부 기념 벚꽃 에디션)       NaN    김호연    9.81     나무옆의자  20210420
# 4            작별인사(밤하늘 에디션)       NaN    김영하    9.48      복복서가  20220502
#
#                                          description pages  \
# 0  ‘우리 시대 최고의 문장가’ ‘작가들의 작가’로 일컬어지는 소설가 김훈의 신작 장편...   308
# 1  김유정문학상 심훈문학대상 이효석문학상 등을 수상하며 문학성을 두루 입증받은 ‘리얼리...   268
# 2  출간 후 1년이 넘도록 독자의 사랑을 받으며 베스트셀러 상위권을 지키고 있는 소설,...   320
# 3  누적 판매 40만부 돌파, 2022년 가장 사랑받는 소설\n★★★전 서점 종합베스트...   268
# 4  『작별인사』 20만 부 돌파 기념 밤하늘 스페셜 에디션 출간!\n“김영하가 쓴 가장...   308
#
#                                               imgUrl  \
# 0  https://contents.kyobobook.co.kr/sih/fit-in/14...
# 1  https://contents.kyobobook.co.kr/sih/fit-in/14...
# 2  https://contents.kyobobook.co.kr/sih/fit-in/14...
# 3  https://contents.kyobobook.co.kr/sih/fit-in/14...
# 4  https://contents.kyobobook.co.kr/sih/fit-in/14...
#
#                               genre_list
# 0  [국내도서, 소설, 한국소설, 역사/대하소설, 장르소설, 역사소설]
# 1               [국내도서, 소설, 한국소설, 한국소설일반]
# 2               [국내도서, 소설, 한국소설, 한국소설일반]
# 3               [국내도서, 소설, 한국소설, 한국소설일반]
# 4               [국내도서, 소설, 한국소설, 한국소설일반]

# %%
url = "https://product.kyobobook.co.kr/detail/S000061532442"
data = requests.get(url).content
soup = bs4.BeautifulSoup(data, "lxml")
print(soup)
# Out:
# <!DOCTYPE html>
# <html data-view="ink" lang="ko">
# <head>
# <meta content="2dlgBOp3K0s6wHjZo_Hkas6yaYPKZIVsmres9vC3F34" name="google-site-verification"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="SEO 기획 정의 내용 반영" name="Author"/>
# <meta content="SEO 기획 정의 내용 반영" name="keywords"/>
# <meta content="SEO 기획 정의 내용 반영" name="description"/>
# <meta content="SEO 기획 정의 내용 반영" name="subject"/>
# <!-- DESC : 성인컨텐츠인 경우 추가하는 meta tag -->
# <!--<meta name="rating" content="adult" />-->
# <!-- 오픈그래프 메타정보 추가 -->
# <meta content="하얼빈 | 김훈 - 교보문고" name="title"/>
# <meta content='하얼빈 | 『칼의 노래』를 넘어서는 깊이와 감동
# 김훈이 반드시 써내야만 했던 일생의 과업‘우리 시대 최고의 문장가’ ‘작가들의 작가’로 일컬어지는 소설가 김훈의 신작 장편소설 『하얼빈』이 출간되었다. 『하얼빈』은 김훈이 작가로 활동하는 내내 인생 과업으로 삼아왔던 특별한 작품이다. 작가는 청년 시절부터 안중근의 짧고 강렬했던 생애를 소설로 쓰려는 구상을 품고 있었고, 안중근의 움직임이 뿜어내는 에너지를 글로 감당하기 위해 오랜 시간을 들여 ‘인간 안중근’을 깊이 이해해나갔다. 그리고 2022년 여름, 치열하고 절박한 집필 끝에 드디어 그 결과물을 세상에 내놓게 되었다.
#
#  『하얼빈』에서는 단순하게 요약되기 쉬운 실존 인물의 삶을 역사적 기록보다도 철저한 상상으로 탄탄하게 재구성하는 김훈의 글쓰기 방식이 빛을 발한다. 이러한 서사는 자연스럽게 김훈의 대표작 『칼의 노래』를 떠올리게 하는데, 『칼의 노래』가 명장으로서 이룩한 업적에 가려졌던 이순신의 요동하는 내면을 묘사했다면 『하얼빈』은 안중근에게 드리워져 있던 영웅의 그늘을 걷어내고 그의 가장 뜨겁고 혼란스러웠을 시간을 현재에 되살려놓는다.
#
# 난세를 헤쳐가야 하는 운명을 마주한 미약한 인간의 내면에 집중하는 김훈의 시선은 『하얼빈』에서 더욱 깊이 있고 오묘한 장면들을 직조해낸다. 소설 안에서 이토 히로부미로 상징되는 제국주의의 물결과 안중근으로 상징되는 청년기의 순수한 열정이 부딪치고, 살인이라는 중죄에 임하는 한 인간의 대의와 윤리가 부딪치며, 안중근이 천주교인으로서 지닌 신앙심과 속세의 인간으로서 지닌 증오심이 부딪친다. 이토록 다양한 층위에서 벌어지는 복합적인 갈등을 날렵하게 다뤄내며 안중근이라는 인물을 바라보는 시야의 차원을 높이는 이 작품은 김훈의 새로운 대표작으로 소개되기에 모자람이 없다.&lt;b&gt; ▶ 『하얼빈』 북트레일러&lt;/b&gt;
# &lt;iframe width="640" height="360" src="https://www.youtube.com/embed/nds4jOX027g" title="영웅이 아닌 청년 안중근을 그린 김훈, 50년동안 마음속에 품어만 왔던 이유는? 『하얼빈』 l [인터뷰]" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen&gt;&lt;/iframe&gt;
# * 출판사의 사정에 따라 서비스가 변경 또는 중지될 수 있습니다.
# * window7의 경우 사운드 연결이 없을시, 동영상 재생에 오류가 발생할 수 있습니다. 이어폰, 스피커 등이 연결되어 있는지 확인 하시고 재생하시기 바랍니다.' name="description"/>
# <meta content="하얼빈 | 김훈 - 교보문고" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://contents.kyobobook.co.kr/sih/fit-in/458x0/pdt/9788954699914.jpg" property="og:image"/>
# <meta content="https://product.kyobobook.co.kr/detail/S000061532442" property="og:url"/>
# <meta content='하얼빈 | 『칼의 노래』를 넘어서는 깊이와 감동
# 김훈이 반드시 써내야만 했던 일생의 과업‘우리 시대 최고의 문장가’ ‘작가들의 작가’로 일컬어지는 소설가 김훈의 신작 장편소설 『하얼빈』이 출간되었다. 『하얼빈』은 김훈이 작가로 활동하는 내내 인생 과업으로 삼아왔던 특별한 작품이다. 작가는 청년 시절부터 안중근의 짧고 강렬했던 생애를 소설로 쓰려는 구상을 품고 있었고, 안중근의 움직임이 뿜어내는 에너지를 글로 감당하기 위해 오랜 시간을 들여 ‘인간 안중근’을 깊이 이해해나갔다. 그리고 2022년 여름, 치열하고 절박한 집필 끝에 드디어 그 결과물을 세상에 내놓게 되었다.
#
#  『하얼빈』에서는 단순하게 요약되기 쉬운 실존 인물의 삶을 역사적 기록보다도 철저한 상상으로 탄탄하게 재구성하는 김훈의 글쓰기 방식이 빛을 발한다. 이러한 서사는 자연스럽게 김훈의 대표작 『칼의 노래』를 떠올리게 하는데, 『칼의 노래』가 명장으로서 이룩한 업적에 가려졌던 이순신의 요동하는 내면을 묘사했다면 『하얼빈』은 안중근에게 드리워져 있던 영웅의 그늘을 걷어내고 그의 가장 뜨겁고 혼란스러웠을 시간을 현재에 되살려놓는다.
#
# 난세를 헤쳐가야 하는 운명을 마주한 미약한 인간의 내면에 집중하는 김훈의 시선은 『하얼빈』에서 더욱 깊이 있고 오묘한 장면들을 직조해낸다. 소설 안에서 이토 히로부미로 상징되는 제국주의의 물결과 안중근으로 상징되는 청년기의 순수한 열정이 부딪치고, 살인이라는 중죄에 임하는 한 인간의 대의와 윤리가 부딪치며, 안중근이 천주교인으로서 지닌 신앙심과 속세의 인간으로서 지닌 증오심이 부딪친다. 이토록 다양한 층위에서 벌어지는 복합적인 갈등을 날렵하게 다뤄내며 안중근이라는 인물을 바라보는 시야의 차원을 높이는 이 작품은 김훈의 새로운 대표작으로 소개되기에 모자람이 없다.&lt;b&gt; ▶ 『하얼빈』 북트레일러&lt;/b&gt;
# &lt;iframe width="640" height="360" src="https://www.youtube.com/embed/nds4jOX027g" title="영웅이 아닌 청년 안중근을 그린 김훈, 50년동안 마음속에 품어만 왔던 이유는? 『하얼빈』 l [인터뷰]" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen&gt;&lt;/iframe&gt;
# * 출판사의 사정에 따라 서비스가 변경 또는 중지될 수 있습니다.
# * window7의 경우 사운드 연결이 없을시, 동영상 재생에 오류가 발생할 수 있습니다. 이어폰, 스피커 등이 연결되어 있는지 확인 하시고 재생하시기 바랍니다.' property="og:description"/>
# <meta content="하얼빈 | 김훈 - 교보문고" name="twitter:title"/>
# <meta content='하얼빈 | 『칼의 노래』를 넘어서는 깊이와 감동
# 김훈이 반드시 써내야만 했던 일생의 과업‘우리 시대 최고의 문장가’ ‘작가들의 작가’로 일컬어지는 소설가 김훈의 신작 장편소설 『하얼빈』이 출간되었다. 『하얼빈』은 김훈이 작가로 활동하는 내내 인생 과업으로 삼아왔던 특별한 작품이다. 작가는 청년 시절부터 안중근의 짧고 강렬했던 생애를 소설로 쓰려는 구상을 품고 있었고, 안중근의 움직임이 뿜어내는 에너지를 글로 감당하기 위해 오랜 시간을 들여 ‘인간 안중근’을 깊이 이해해나갔다. 그리고 2022년 여름, 치열하고 절박한 집필 끝에 드디어 그 결과물을 세상에 내놓게 되었다.
#
#  『하얼빈』에서는 단순하게 요약되기 쉬운 실존 인물의 삶을 역사적 기록보다도 철저한 상상으로 탄탄하게 재구성하는 김훈의 글쓰기 방식이 빛을 발한다. 이러한 서사는 자연스럽게 김훈의 대표작 『칼의 노래』를 떠올리게 하는데, 『칼의 노래』가 명장으로서 이룩한 업적에 가려졌던 이순신의 요동하는 내면을 묘사했다면 『하얼빈』은 안중근에게 드리워져 있던 영웅의 그늘을 걷어내고 그의 가장 뜨겁고 혼란스러웠을 시간을 현재에 되살려놓는다.
#
# 난세를 헤쳐가야 하는 운명을 마주한 미약한 인간의 내면에 집중하는 김훈의 시선은 『하얼빈』에서 더욱 깊이 있고 오묘한 장면들을 직조해낸다. 소설 안에서 이토 히로부미로 상징되는 제국주의의 물결과 안중근으로 상징되는 청년기의 순수한 열정이 부딪치고, 살인이라는 중죄에 임하는 한 인간의 대의와 윤리가 부딪치며, 안중근이 천주교인으로서 지닌 신앙심과 속세의 인간으로서 지닌 증오심이 부딪친다. 이토록 다양한 층위에서 벌어지는 복합적인 갈등을 날렵하게 다뤄내며 안중근이라는 인물을 바라보는 시야의 차원을 높이는 이 작품은 김훈의 새로운 대표작으로 소개되기에 모자람이 없다.&lt;b&gt; ▶ 『하얼빈』 북트레일러&lt;/b&gt;
# &lt;iframe width="640" height="360" src="https://www.youtube.com/embed/nds4jOX027g" title="영웅이 아닌 청년 안중근을 그린 김훈, 50년동안 마음속에 품어만 왔던 이유는? 『하얼빈』 l [인터뷰]" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen&gt;&lt;/iframe&gt;
# * 출판사의 사정에 따라 서비스가 변경 또는 중지될 수 있습니다.
# * window7의 경우 사운드 연결이 없을시, 동영상 재생에 오류가 발생할 수 있습니다. 이어폰, 스피커 등이 연결되어 있는지 확인 하시고 재생하시기 바랍니다.' name="twitter:description"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="https://product.kyobobook.co.kr/detail/S000061532442" name="twitter:url"/>
# <meta content="https://contents.kyobobook.co.kr/sih/fit-in/458x0/pdt/9788954699914.jpg" name="twitter:image"/>
# <meta content="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-144x144-precomposed.png" name="msapplication-TileImage"/>
# <meta content="#222222" name="msapplication-TileColor"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-700x700-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="700x700"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-180x180-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="180x180"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-167x167-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="167x167"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-152x152-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="152x152"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-144x144-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="144x144"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-120x120-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="120x120"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-114x114-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="114x114"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-80x80-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="80x80"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-72x72-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="72x72"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-60x60-precomposed.png" rel="apple-touch-icon-precomposed apple-touch-icon" sizes="60x60"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/apple-touch-icon-57x57-precomposed.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/favicon_256x256.png" rel="shortcut icon" sizes="256x256"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/favicon_196x196.png" rel="shortcut icon" sizes="196x196"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/favicon_128x128.png" rel="shortcut icon" sizes="128x128"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/favicon_48x48.png" rel="shortcut icon" sizes="48x48"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/favicon_32x32.png" rel="shortcut icon" sizes="32x32"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/favicon_16x16.png" rel="shortcut icon"/>
# <!-- favicon -->
# <!-- <link rel="icon" th:href="${cdnURI} + '/images/favicon/kyobo.ico'" type="image/x-icon"> -->
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/favicon_128x128.png" rel="icon" sizes="128x128" type="image/png"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/favicon_64x64.png" rel="icon" sizes="64x64" type="image/png"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/favicon/favicon_32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <!-- TODO: biz meta data -->
# <title>하얼빈 | 김훈 - 교보문고</title>
# <link href="//fonts.googleapis.com/css2?family=Noto+Sans+KR:wght@400;500;700&amp;family=Roboto:wght@400;500;700&amp;display=swap" rel="stylesheet"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/vendors/jquery-ui-1.12.1/jquery-ui.min.css" rel="stylesheet"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/vendors/star-rating/css/star-rating.min.css" rel="stylesheet"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/css/loading.css" rel="stylesheet"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/vendors/swiper/v4/swiper.min.css" rel="stylesheet"/>
# <link href="https://contents.kyobobook.co.kr/resources/fo/vendors/simplebar/5.3.3/simplebar.min.css" rel="stylesheet"/>
# <link data-name="kbb-cm-style" href="https://contents.kyobobook.co.kr/resources/fo/css/style_ink.css" rel="stylesheet"/>
# <!-- KbbJS 필수라이브러리 : jquery + lodash + js.cookie -->
# <script src="https://contents.kyobobook.co.kr/resources/fo/vendors/essential-vendors.min.js"></script>
# <script src="https://contents.kyobobook.co.kr/resources/fo/vendors/polyfills.min.js"></script>
# <!-- 통합검색 스크립트 -->
# <script src="https://contents.kyobobook.co.kr/resources/fo/js/search/kyobo_search_auto.js"></script>
# <!-- [KbbJS] 로더 스크립트 -->
# <script src="https://contents.kyobobook.co.kr/resources/fo/vendors/lottie-5.9.4/lottie.min.js"></script>
# <script src="https://contents.kyobobook.co.kr/resources/fo/js/kbb-loading.js"></script>
# <script src="https://contents.kyobobook.co.kr/resources/fo/js/kbbjs-loader.js"></script>
# <!-- GA360스크립트 -->
# <script> window.dataLayer = window.dataLayer || [];</script>
# <script src="https://contents.kyobobook.co.kr/resources/fo/js/ga360/common-vars.js"></script>
# <script src="https://contents.kyobobook.co.kr/resources/fo/js/ga360/util.js"></script>
# <script>
#         // IIFE
#         ;(function () {
#             // --------------------- [KbbJS/SSR] 서버 환경변수 전달
#             var CDN_URL = "https:\/\/contents.kyobobook.co.kr\/resources\/fo"
#
#             var tmpArr = CDN_URL.match(/((https?:)?\/\/[^/]+)(\/.*)/)
#             var cdnHost = tmpArr[1]
#             var cdnBaseURL = tmpArr[3]
#             KbbJS.setOption('service.cdn.host', cdnHost)
#             KbbJS.setOption('service.cdn.baseURL', cdnBaseURL)
#
#             var hostname = cdnHost.replace(/^(https?:)?[/]*/, '')
#
#             /**
#              * KbbJS 라이브러리 경로 설정
#              */
#             var KbbjsURL = "\/lib\/kbb-js"
#             if (!/^(https?:|\/\/)/.test(KbbjsURL)) {
#                 KbbjsURL = CDN_URL + KbbjsURL
#             }
#
#             /**
#              * KbbJS 버전 분기(stable, latest, stage, local)
#              * - TODO: 운영계는 stable 버전 반영
#              */
#             var KBBJS_VER = 'stage/20221009-073737'
#
#             // TODO: 로컬호스트 패턴 리팩토링
#             var isLocalhost = /^(local|172\.29\.)/.test(hostname)
#             if (isLocalhost) KBBJS_VER = 'local'
#
#             // KbbJS 라이브러리 경로 설정: [CDN_BASEURL]/lib/kbb-js
#             KbbjsURL += '/' + KBBJS_VER
#             KbbJS.setOption('loader.baseURL', KbbjsURL)
#
#             // 디바이스 정보 설정
#             KbbJS.setOption('ua.device', {
#                 isMobile: false,
#                 isMobileApp: false,
#                 isIOS: false,
#                 isAndroid: false,
#                 isMSIE: false,
#                 isMac: false
#             })
#
#             /**
#              * 서비스 호스트 설정
#              */
#             var oServiceData = {"hosts":{"eLibrary":null,"product":"https:\/\/product.kyobobook.co.kr","ecash":"https:\/\/ecash.kyobobook.co.kr","best":"https:\/\/best.kyobobook.co.kr","ebookProduct":"https:\/\/ebook-product.kyobobook.co.kr","bookcast":"https:\/\/casting.kyobobook.co.kr","search":"https:\/\/search.kyobobook.co.kr","ebook":"https:\/\/ebook.kyobobook.co.kr","member":"https:\/\/mmbr.kyobobook.co.kr","myroom":"https:\/\/my.kyobobook.co.kr","event":"https:\/\/event.kyobobook.co.kr","welcome":"https:\/\/www.kyobobook.co.kr","sam":"https:\/\/sam.kyobobook.co.kr","order":"https:\/\/order.kyobobook.co.kr"}}
#             var oServiceHosts = _.get(oServiceData, 'hosts', {})
#             _.forEach(_.keys(oServiceHosts), function (prop) {
#                 var value = _.get(oServiceHosts, prop)
#                 if (value == null) {
#                     // 기본 호스트 설정
#                     switch (prop) {
#                         case 'welcome': value = 'www'; break
#                         case 'myroom': value = 'my'; break
#                         case 'bookcast': value = 'casting'; break
#                         case 'member': value = 'mmbr'; break
#                         case 'ebookProduct':
#                             value = 'ebook-product'
#                             break
#                         case 'eLibrary':
#                             value = 'elibrary'
#                             break
#                         case 'product':
#                         case 'event':
#                         case 'order':
#                         case 'search':
#                         case 'best':
#                         case 'ebook':
#                         case 'sam':
#                         case 'ecash':
#                             value = prop
#                             break
#                     }
#                     if (value == null) return
#                     value = 'https://' + value + '.kyobobook.co.kr'
#                 }
#                 KbbJS.setOption('service.' + prop + '.host', value)
#             })
#
#             // console.log('[SRV_LOADER_BASEURL]:', KbbJS.getOption('loader.baseURL'))
#             // console.log('[SRV_UA_DEVICE]:', KbbJS.getOption('ua.device'));
#             // console.log('[SRV_SERVICE]:', KbbJS.getOption('service'));
#
#             /** RTS 관련 스크립트 로드 */
#             window._eglconf = window._eglconf || {}
#             window._eglconf.forceTrackVisit = true
#             var path = document.location.hostname
#             // 운영
#             var cuid = 'd37a866b-3e69-4570-8ef2-36e01b487dd4'
#             var pickCuid = '4ffe4f3c-7219-4bd2-a7ae-eba4aefc9b19'
#             if (/(\.ndev|localhost|local\.)/.test(path)) {
#               // 개발
#               cuid = 'a7319bca-2a26-497d-b1aa-9b410e1193f6'
#               pickCuid = '2e514b09-86fe-4c69-8ec9-0a8c8416d2ae'
#             } else if (/\.n(stg|prd)/.test(path)) {
#               // 스테이지
#               cuid = '2af19936-d725-4320-b73e-6e8a3f29ad5f'
#               pickCuid = 'f5fbf232-7e27-4ca3-b922-b3a56d79780b'
#             }
#             _.set(window, '_eglqueue', [
#               ['setVar', 'cuid', cuid],
#               ['setVar', 'userId', null],
#               ['track', 'visit'],
#               ['reset'],
#               ['setVar', 'cuid', pickCuid],
#               ['setVar', 'userId', null],
#               ['track', 'visit'],
#             ])
#           }())
#
#           /** TODO_COMMENT */
#           $('<script/>').attr({
#             src: 'https://logger.eigene.io/js/logger.min.js',
#             defer: true
#           }).appendTo('body')
#     </script>
# <!-- [KbbJS] 전체 서비스 공통 변수 설정 스크립트 -->
# <script src="https://contents.kyobobook.co.kr/resources/fo/js/common-vars.js"></script>
# <script type="application/ld+json">
# {
#          @context:"http://schema.org",
#         "@type":"Book",
#         "name" : 하얼빈,
#         "bookFormat" : "https://schema.org/Book",
#         "datePublished" : 20220803,
#         "genre":소설,
#         "image":https://contents.kyobobook.co.kr/sih/fit-in/458x0/pdt/9788954699914.jpg,
#         "description" : 하얼빈 | 『칼의 노래』를 넘어서는 깊이와 감동
# 김훈이 반드시 써내야만 했던 일생의 과업‘우리 시대 최고의 문장가’ ‘작가들의 작가’로 일컬어지는 소설가 김훈의 신작 장편소설 『하얼빈』이 출간되었다. 『하얼빈』은 김훈이 작가로 활동하는 내내 인생 과업으로 삼아왔던 특별한 작품이다. 작가는 청년 시절부터 안중근의 짧고 강렬했던 생애를 소설로 쓰려는 구상을 품고 있었고, 안중근의 움직임이 뿜어내는 에너지를 글로 감당하기 위해 오랜 시간을 들여 ‘인간 안중근’을 깊이 이해해나갔다. 그리고 2022년 여름, 치열하고 절박한 집필 끝에 드디어 그 결과물을 세상에 내놓게 되었다.
#
#  『하얼빈』에서는 단순하게 요약되기 쉬운 실존 인물의 삶을 역사적 기록보다도 철저한 상상으로 탄탄하게 재구성하는 김훈의 글쓰기 방식이 빛을 발한다. 이러한 서사는 자연스럽게 김훈의 대표작 『칼의 노래』를 떠올리게 하는데, 『칼의 노래』가 명장으로서 이룩한 업적에 가려졌던 이순신의 요동하는 내면을 묘사했다면 『하얼빈』은 안중근에게 드리워져 있던 영웅의 그늘을 걷어내고 그의 가장 뜨겁고 혼란스러웠을 시간을 현재에 되살려놓는다.
#
# 난세를 헤쳐가야 하는 운명을 마주한 미약한 인간의 내면에 집중하는 김훈의 시선은 『하얼빈』에서 더욱 깊이 있고 오묘한 장면들을 직조해낸다. 소설 안에서 이토 히로부미로 상징되는 제국주의의 물결과 안중근으로 상징되는 청년기의 순수한 열정이 부딪치고, 살인이라는 중죄에 임하는 한 인간의 대의와 윤리가 부딪치며, 안중근이 천주교인으로서 지닌 신앙심과 속세의 인간으로서 지닌 증오심이 부딪친다. 이토록 다양한 층위에서 벌어지는 복합적인 갈등을 날렵하게 다뤄내며 안중근이라는 인물을 바라보는 시야의 차원을 높이는 이 작품은 김훈의 새로운 대표작으로 소개되기에 모자람이 없다.<b> ▶ 『하얼빈』 북트레일러</b>
# <iframe width="640" height="360" src="https://www.youtube.com/embed/nds4jOX027g" title="영웅이 아닌 청년 안중근을 그린 김훈, 50년동안 마음속에 품어만 왔던 이유는? 『하얼빈』 l [인터뷰]" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# * 출판사의 사정에 따라 서비스가 변경 또는 중지될 수 있습니다.
# * window7의 경우 사운드 연결이 없을시, 동영상 재생에 오류가 발생할 수 있습니다. 이어폰, 스피커 등이 연결되어 있는지 확인 하시고 재생하시기 바랍니다.,
#         /*"keywords":"맨부커국제상, 맨부커인터내셔널상, 이상문학상, 한국소설, 상처, 죽음, 욕망, 채식주의자, 한강, 창비, 9788936433598, 8936433598",*/
#         "author": {
#              @type:"Person",
#                name:김훈,
#         },
#         "publisher": {
#              @type:"Organization",
#                name:문학동네,
#         },
#         "url": https://product.kyobobook.co.kr/detail/S000061532442,
#         "workExample" : [{
#              @type: "Book",
#                isbn: 9788954699914 ( 895469991X ),
#                potentialAction:{
#                  @type:"ReadAction",
#                    expectsAcceptanceOf:{
#                       @type:"Offer",
#                         Price:16000,
#                         priceCurrency:"KRW",
#                         availability: "https://schema.org/Book"
#
#
#         }]
#
#         ,"aggregateRating": {
#              @type: "AggregateRating",
#                worstRating: "0",
#                bestRating: "10",
#                ratingValue: 9.8,
#                ratingCount: 361
#         }
#
# }
# </script>
# <link href="https://contents.kyobobook.co.kr/resources/fo/css/product_ink.css" rel="stylesheet"/>
# <meta content="product" property="eg:type"/>
# <meta content="d37a866b-3e69-4570-8ef2-36e01b487dd4" property="eg:cuid"/>
# <meta content="S000061532442" property="eg:itemId"/>
# <meta content="하얼빈" property="eg:itemName"/>
# <meta content="https://contents.kyobobook.co.kr/pdt/S000061532442.jpg" property="eg:itemImage"/>
# <meta content="9788954699914" property="eg:itemUrl"/>
# <meta content="" property="eg:originalPrice"/>
# <meta content="" property="eg:salePrice"/>
# <meta content="SGK" property="eg:category1"/>
# <meta content="" property="eg:category2"/>
# <meta content="" property="eg:category3"/>
# <meta content="" property="eg:category4"/>
# <meta content="" property="eg:category5"/>
# <meta content="" property="eg:category1_name"/>
# <meta content="" property="eg:category2_name"/>
# <meta content="" property="eg:category3_name"/>
# <meta content="" property="eg:category4_name"/>
# <meta content="" property="eg:category5_name"/>
# <meta content="" property="eg:brandId"/>
# <meta content="" property="eg:brandName"/>
# <meta content="" property="eg:regDate"/>
# <meta content="" property="eg:updateDate"/>
# <meta content="" property="eg:expireDate"/>
# <meta content="" property="eg:stock"/>
# <meta content="" property="eg:state"/>
# <meta content="" property="eg:description"/>
# <meta content="" property="eg:extraImage"/>
# <meta content="" property="eg:locale"/>
# <meta content="" property="eg:isNew"/>
# <meta content="" property="eg:gender"/>
# <meta content="" property="eg:etc1"/>
# <meta content="" property="eg:etc2"/>
# <meta content="" property="eg:etc3"/>
# <meta content="" property="eg:etc4"/>
# <meta content="" property="eg:etc5"/>
# <meta content="" property="eg:etc6"/>
# <meta content="" property="eg:etc7"/>
# <meta content="" property="eg:etc8"/>
# <meta content="" property="eg:etc9"/>
# <meta content="" property="eg:etc10"/>
# <script type="text/javascript">
#     window._eglqueue = window._eglqueue || [];
#     var path = document.location.hostname
#     // 운영
#     var cuid = 'd37a866b-3e69-4570-8ef2-36e01b487dd4'
#     var pickCuid = '4ffe4f3c-7219-4bd2-a7ae-eba4aefc9b19'
#     if (/(\.ndev|localhost|local\.)/.test(path)) {
#       // 개발
#       cuid = 'a7319bca-2a26-497d-b1aa-9b410e1193f6'
#       pickCuid = '2e514b09-86fe-4c69-8ec9-0a8c8416d2ae'
#     } else if (/\.n(stg|prd)/.test(path)) {
#       // 스테이지
#       cuid = '2af19936-d725-4320-b73e-6e8a3f29ad5f'
#       pickCuid = 'f5fbf232-7e27-4ca3-b922-b3a56d79780b'
#     }
#     // RTS
#     _eglqueue.push(['setVar', 'cuid', cuid]);
#     // _eglqueue.push(['setVar', 'itemId', "9788954699914"]);
#     _eglqueue.push(['setVar', 'itemId', "S000061532442"]);
#     _eglqueue.push(['setVar', 'userId', ""]);
#     _eglqueue.push(['setVar', 'categoryId', "SGK"]);
#     _eglqueue.push(['setVar', 'brandId', '']);
#     _eglqueue.push(['track', 'view']);
#     _eglqueue.push(['track', 'product']);
#     _eglqueue.push(['reset']);
#
#     // Picks
#     _eglqueue.push(['setVar', 'cuid', pickCuid]);
#     // _eglqueue.push(['setVar', 'itemId', "9788954699914"]);
#     _eglqueue.push(['setVar', 'itemId', "S000061532442"]);
#     _eglqueue.push(['setVar', 'userId', ""]);
#     _eglqueue.push(['setVar', 'itemDvsn', "KOR"]);
#     _eglqueue.push(['setVar', 'categoryId', '']);
#     _eglqueue.push(['setVar', 'brandId', '']);
#     _eglqueue.push(['track', 'view']);
#     (function (s, x) {
#         s = document.createElement('script'); s.type = 'text/javascript';
#         s.async = true; s.defer = true; s.src = 'https://logger.eigene.io/js/logger.min.js';
#         x = document.getElementsByTagName('script')[0]; x.parentNode.insertBefore(s, x);
#     })();
# </script>
# <script>
#         // 화면 view type code
#         KbbJS.setOption('plugins.ui-product.type', "KOR")
#         // 판매상품ID
#         KbbJS.setOption('plugins.ui-product.pid', "S000061532442")
#         // 결합상품 판매상품ID
#         KbbJS.setOption('plugins.ui-product.combiSaleCode', "")
#         // 상품코드(바코드)
#         KbbJS.setOption('plugins.ui-product.barcode', "9788954699914")
#         // 판매상품구분코드
#         KbbJS.setOption('plugins.ui-product.salecode', "KOR")
#         // 판매상품분류코드
#         KbbJS.setOption('plugins.ui-product.saleClstCode', "010105")
#         // 판매상품그룹구분코드
#         KbbJS.setOption('plugins.ui-product.saleGrpCode', "SGK")
#         // 판매상품 가격
#         KbbJS.setOption('plugins.ui-product.salePrice', "14400")
#         // 오픈마켓 입점사 ID
#         KbbJS.setOption('plugins.ui-product.sellerId', "")
#         // 오픈마켓 구성 ID
#         KbbJS.setOption('plugins.ui-product.opnCode', "")
#         // 상품 상세 접근시 최근 본 컨텐츠 추가
#         KbbJS.addRecentlyContent({ catg: 'p', type: 'KOR', id: 'S000061532442' })
#         // 판매제한연령
#         KbbJS.setOption('plugins.ui-product.saleLmttAge', "0")
#         // 컬처 구성상품 판매상품ID
#         KbbJS.setOption('plugins.ui-product.cnfgSaleCmdtId', "")
#         // 사은품 여부
#         KbbJS.setOption('plugins.ui-product.isGifts', "Y")
#     </script>
# <script>
#             // AD 광고에 필요한 "대"카테고리 코드값
#             KbbJS.setOption('plugins.ui-product.categoryCode', "01")
#         </script>
# <script src="https://contents.kyobobook.co.kr/resources/fo/js/ui-onk/options.js"></script>
# <script>KbbJS.load({ env: 'production' })</script>
# </head>
# <body>
# <div class="loading_box show" id="KbbLoading">
# <div class="loading_box_inner">
# <div class="loading_target"></div>
# </div>
# <div class="loading_dimmed"></div>
# </div>
# <div class="skip_nav_wrap">
# <a href="#contents">본문 바로가기</a>
# </div>
# <!-- BODY_WRAPPER -->
# <div class="wrapper contents_detail_view" id="mainDiv">
# <header class="header_wrapper has_banner perform sps" id="welcome_header_wrap">
# <div class="service_mall_wrap">
# <div class="service_mall_inner">
# <div class="service_mall_box">
# <ul class="service_mall_list">
# <li class="service_mall_item">
# <svg viewbox="0 0 565 33" xmlns="http://www.w3.org/2000/svg"> <!--<g transform="translate(0 0)">
#         <a id="mallLinkEbook" href="#" class="service_mall_link link_kyobo">
#             <use href="/assets/common/images/img_service_mall_tab.svg#pathTab" />
#         </a>
#         <text x="64" y="15" dy=".5em" aria-labelledby="mallLinkEbook">교보문고</text>
#     </g>--> <g transform="translate(0 0)">
# <a class="service_mall_link link_ebook" href="https://ebook.kyobobook.co.kr/" id="mallLinkEbook">
# <use href="/assets/images/common/img_service_mall_tab.svg#pathTab"></use> <!-- 수정 211207 fill color 전페이지 공통 수정 --> </a>
# <text aria-labelledby="mallLinkEbook" dy=".5em" font-size="14px" x="64" y="15">
#          eBook
#         </text>
# </g> <g transform="translate(87 0)">
# <a class="service_mall_link link_sam" href="https://sam.kyobobook.co.kr/dig/pnd/showcase?pageNo=12" id="mallLinkSAM">
# <use href="/assets/images/common/img_service_mall_tab.svg#pathTab"></use> </a>
# <text aria-labelledby="mallLinkSAM" dy=".5em" x="64" y="13">
#          sam
#         </text>
# </g> <!-- 수정 211207 핫트랙스, 매장안내 노출 순서 전페이지 공통 변경 --> <g transform="translate(174 0)">
# <a class="service_mall_link link_hot_tracks" href="https://hottracks.kyobobook.co.kr" id="mallLinkHotTracks">
# <use href="/assets/images/common/img_service_mall_tab.svg#pathTab"></use> </a>
# <text aria-labelledby="mallLinkHotTracks" dy=".5em" x="64" y="15">
#          핫트랙스
#         </text>
# </g> <g transform="translate(261 0)">
# <a class="service_mall_link link_store" href="https://www.kyobobook.co.kr/store" id="mallLinkStore">
# <use href="/assets/images/common/img_service_mall_tab.svg#pathTab"></use> </a>
# <text aria-labelledby="mallLinkStore" dy=".5em" x="64" y="15">
#          매장안내
#         </text>
# </g> <!-- // 수정 211207 핫트랙스, 매장안내 노출 순서 전페이지 공통 변경 --> <g transform="translate(348 0)">
# <a class="service_mall_link" href="https://www.tocsoda.co.kr/mainView" id="mallLinkTok" target="_blank">
# <use href="/assets/images/common/img_service_mall_tab_link_tok.svg#pathTabLink"></use> </a>
# <text aria-labelledby="mallLinkTok" dy=".5em" x="64" y="15">
#          톡소다
#         </text>
# </g> <g transform="translate(437 0)">
# <a class="service_mall_link" href="https://storynew.kyobobook.co.kr/story/main/initMain.ink" id="mallLinkStory" target="_blank">
# <use href="/assets/images/common/img_service_mall_tab_link.svg#pathTabLink"></use> </a>
# <text aria-labelledby="mallLinkStory" class="has_arrow" dy=".5em" x="64" y="15">
#          스토리
#         </text>
# </g>
# </svg> </li>
# <li class="service_mall_item brand_more"> <button class="btn_brand_more" type="button"> <span class="text">브랜드 더보기</span> </button>
# <div class="brand_more_list_box">
# <div class="custom_scroll_wrap">
# <ul class="brand_more_list">
# <li class="brand_more_item"> <a class="brand_more_link" href="https://www.kyobobook.co.kr/"> <span class="img_box"><img alt="교보문고 BI" src="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_brand_more_kyobo.png"/></span> <span class="brand_name">교보문고</span> </a> </li>
# <li class="brand_more_item"> <a class="brand_more_link" href="https://ebook.kyobobook.co.kr/"> <span class="img_box"><img alt="교보문고 eBook BI" src="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_brand_more_ebook.png"/></span> <span class="brand_name">eBook</span> </a> </li>
# <li class="brand_more_item"> <a class="brand_more_link" href="https://sam.kyobobook.co.kr/dig/pnd/showcase?pageNo=12"> <span class="img_box"><img alt="교보문고 sam BI" src="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_brand_more_sam.png"/></span> <span class="brand_name">sam</span> </a> </li>
# <li class="brand_more_item"> <a class="brand_more_link" href="https://hottracks.kyobobook.co.kr"> <span class="img_box"><img alt="핫트랙스 BI" src="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_brand_more_hot_tracks.png"/></span> <span class="brand_name">핫트랙스</span> </a> </li>
# <li class="brand_more_item"> <a class="brand_more_link" href="https://www.kyobobook.co.kr/store"> <span class="img_box"><img alt="매장안내 BI" src="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_brand_more_store.png"/></span> <span class="brand_name">매장안내</span> </a> </li>
# <li class="brand_more_item" id="brand_soda"> <a class="brand_more_link" href="https://www.tocsoda.co.kr/mainView" target="_blank"> <span class="img_box"><img alt="톡소다 BI" src="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_brand_more_toc_soda.png"/></span> <span class="brand_name">톡소다</span> </a> </li>
# <li class="brand_more_item" id="brand_story"> <a class="brand_more_link" href="https://storynew.kyobobook.co.kr/story/main/initMain.ink" target="_blank"> <span class="img_box"><img alt="스토리 BI" src="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_brand_more_story.png"/></span> <span class="brand_name">스토리</span> </a> </li>
# <li class="brand_more_item" id="brand_morning"> <a class="brand_more_link" href="http://bm.kyobobook.co.kr/common/greeting.do" target="_blank"> <span class="img_box"><img alt="북모닝 BI" src="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_brand_more_book_morning@2x.png"/></span> <span class="brand_name">북모닝</span> </a> </li>
# <li class="brand_more_item"> <a class="brand_more_link" href="http://www.kyoboreadingtree.com" target="_blank"> <span class="img_box"><img alt="리딩트리 BI" src="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_brand_more_reading_tree@2x.png"/></span> <span class="brand_name">리딩트리</span> </a> </li>
# <li class="brand_more_item"> <a class="brand_more_link" href="https://product.kyobobook.co.kr/pod/service?pageNm=personalpub" target="_blank"> <span class="img_box"><img alt="퍼플 BI" src="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_brand_more_pubple@2x.png"/></span> <span class="brand_name">퍼플</span> </a> </li>
# <li class="brand_more_item"> <a class="brand_more_link" href="https://www.vora.co.kr/" target="_blank"> <span class="img_box"><img alt="보라 BI" src="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_brand_more_vora@2x.png"/></span> <span class="brand_name">보라</span> </a> </li>
# <li class="brand_more_item"> <a class="brand_more_link" href="https://kkoomming.notion.site/1921a1f562f340c6a364c230f3331cbd" target="_blank"> <span class="img_box"><img alt="꾸밍 BI" src="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_brand_more_kkoomming@2x.png"/></span> <span class="brand_name">꾸밍</span> </a> </li>
# </ul>
# </div>
# </div> </li>
# </ul>
# </div>
# <div class="customer_service_box">
# <ul class="customer_service_list">
# <li class="customer_service_item" style="display: none;"><a class="util_link" href="https://mmbr.kyobobook.co.kr/join">회원가입</a></li>
# <li class="customer_service_item" style="display: none;"><a class="util_link">로그인</a></li>
# <li class="customer_service_item member_benefit"> <button class="btn_member_benefit" type="button"><span class="text">회원혜택</span></button>
# <ul class="member_benefit_list">
# <li class="member_benefit_item"><a class="member_benefit_link" href="https://mmbr.kyobobook.co.kr/benefit">교보북클럽</a></li>
# <li class="member_benefit_item"><a class="member_benefit_link" href="https://mmbr.kyobobook.co.kr/benefit/grade">등급별 혜택</a></li>
# <li class="member_benefit_item"><a class="member_benefit_link" href="https://mmbr.kyobobook.co.kr/benefit/new">신규회원 혜택</a></li>
# <li class="member_benefit_item"><a class="member_benefit_link" href="https://mmbr.kyobobook.co.kr/benefit/discount">제휴포인트/상품권</a></li>
# <li class="member_benefit_item"><a class="member_benefit_link" href="https://mmbr.kyobobook.co.kr/benefit/service">참좋은교보문고</a></li>
# <li class="member_benefit_item"><a class="member_benefit_link" href="https://mmbr.kyobobook.co.kr/benefit/prestige">Prestige Lounge</a></li>
# </ul> </li>
# <li class="customer_service_item"><a class="util_link" href="https://www.kyobobook.co.kr/cscenter">고객센터</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="header_inner">
# <div class="gnb_search_wrap">
# <h1 class="logo_box"> <a class="logo_link" href="https://www.kyobobook.co.kr/"> <span class="hidden">교보문고</span> </a> </h1>
# <div class="gnb_search_box">
# <div class="form_sel" data-class="type_gnb"> <select id="gbCode" title="검색유형선택"> <option value="TOT">통합검색</option> <option value="KBO">교보문고</option> <option value="EBK">eBook</option> <option value="SAM">sam</option> <option value="HTS">핫트랙스</option> </select>
# </div>
# <div class="search_input_wrap">
# <input autocomplete="off" class="ip_gnb_search" id="searchKeyword" title="통합검색어 입력" type="search" value=""/>
# <input id="searchBoxEventurl" name="searchBoxEventurl" type="hidden" value=""/>
# <script>
#             jQuery(function () {
#                 jQuery.getJSON('/api/adv?url=/INK/ink_wel_new/ink_wel@wel_02?callback=', function (data) {
#                     $(".ip_gnb_search").attr("placeholder", data[0].text);
#                     $('#searchBoxEventurl').val(data[0].linkUrl);
#                 });
#             });
#         </script> <button class="btn_ip_clear" type="button"> <span class="hidden">초기화</span> </button>
# </div> <a class="btn_gnb_search" data-role="gnb-search-submit" href="javascript:goAutoSearchLayer()"> <span class="hidden">검색</span> </a>
# </div>
# <ul class="user_menu_list">
# <li class="user_menu_item cart"> <a class="user_menu_link" href="https://order.kyobobook.co.kr/cart"> <span class="hidden">장바구니</span> <!-- DESC :: 0개인경우 count 영역 미노출 / 최대 99 --> <span class="cnt" data-kbbfn="cart-size" style="display:none;"></span> </a> </li> <!-- DESC : 로그인 후 li.user_menu_item [ login ] class 추가 -->
# <li class="user_menu_item my"> <a class="user_menu_link" href="#"> <span class="img_box no_img"> <img/> </span> <span class="hidden">마이</span><!-- 수정 220428 메뉴명 변경(마이) --> </a> </li>
# </ul> <!-- DESC : 레이어 활성화 시 [ active ] class 추가 -->
# <div class="auto_complete_wrap auto_complete_maintain" id="hFrame">
# <div class="search_content_wrap inKeyword">
# </div>
# <div class="search_content_wrap noKeyword">
# <div class="recommend_keyword_area">
# <div class="title_wrap title_size_def">
# <p class="title_heading">추천 검색어</p>
# </div>
# <div class="tag_wrap" id="recommendKeywordBox">
# </div>
# </div>
# <div class="keyword_contents_area">
# <div class="recent_keyword_box">
# </div>
# <div class="keyword_prod_box" id="keyWordProdBox">
# </div>
# <div class="hot_keyword_box" id="hotKeywordBox">
# <div class="title_wrap title_size_def">
# <p class="title_heading">실시간 인기 검색어</p>
# <div class="right_area"> <!-- form_sel --> <!--<div class="form_sel" data-class="type_arw auto_complete_maintain">
#                             <select title="연령기준 정렬" id="ageSel">
#                                 <option value="">전연령</option>
#                                 <option value="10">10대</option>
#                                 <option value="20">20대</option>
#                                 <option value="30">30대</option>
#                                 <option value="40">40대↑</option>
#                             </select>
#                         </div>--> <!-- //form_sel --> <!-- form_sel --> <!--<div class="form_sel" data-class="type_arw auto_complete_maintain">
#                             <select title="성별기준 정렬" id="genderSel">
#                                 <option value="">전성별</option>
#                                 <option value="1">남성</option>
#                                 <option value="2">여성</option>
#                             </select>
#                         </div>--> <!-- //form_sel -->
# </div>
# </div>
# <div class="hot_keyword_list_wrap">
# </div>
# </div>
# </div>
# <div class="util_area"> <a class="btn_xs btn_light_gray" href="javascript:goDetailSearch();"><span class="ico_search"></span><span class="text">상세검색</span></a> <a class="btn_xs btn_line_gray" href="javascript:goCsCenter();"><span class="ico_link"></span><span class="text">도움말</span></a>
# </div>
# </div> <button class="btn_layer_close" id="close_search_auto" type="button"><span class="ico_layer_close"></span><span class="hidden">닫기</span></button>
# </div>
# </div>
# <nav class="gnb_wrap">
# <div class="anb_wrap"> <button class="btn_anb" type="button"><span class="hidden">전체메뉴</span></button>
# <div class="anb_area">
# <div class="tab_wrap">
# <div class="tab_list_wrap">
# <ul class="tabs">
# <li class="tab_item"><a class="tab_link" href="#tabAnbCategory"><span class="tab_text">카테고리 전체보기</span></a></li>
# <li class="tab_item"><a class="tab_link" href="#tabAnbService"><span class="tab_text">서비스 전체보기</span></a></li>
# </ul>
# </div>
# <div class="tab_content" id="tabAnbCategory">
# <div class="tab_wrap type_md channel">
# <div class="tab_list_wrap">
# <ul class="tabs">
# <li class="tab_item"><a class="tab_link" href="#tabAnbCategoryKyobo"><span class="tab_text">교보문고</span></a></li>
# <li class="tab_item"><a class="tab_link" href="#tabAnbCategoryEbook"><span class="tab_text">eBook</span></a></li>
# <li class="tab_item"><a class="tab_link" href="#tabAnbCategorySam"><span class="tab_text">sam</span></a></li>
# <li class="tab_item"><a class="tab_link" href="#tabAnbCategoryHotTracks"><span class="tab_text">핫트랙스</span></a></li>
# </ul>
# </div>
# <div class="tab_content anb_category" id="tabAnbCategoryKyobo">
# <div class="anb_category_inner">
# <div class="tab_wrap category">
# <div class="tab_list_wrap">
# <ul class="tabs">
# <li class="tab_item"> <a class="tab_link" href="#tabAnbCategorySub01"> <span class="tab_text">국내도서</span> </a> </li>
# <li class="tab_item"> <a class="tab_link" href="#tabAnbCategorySub02"> <span class="tab_text">서양도서</span> </a> </li>
# <li class="tab_item"> <a class="tab_link" href="#tabAnbCategorySub03"> <span class="tab_text">일본도서</span> </a> </li>
# <li class="tab_item"> <a class="tab_link" href="#tabAnbCategorySub04"> <span class="tab_text">교보Only</span> </a> </li>
# </ul>
# </div>
# <div class="tab_content has_banner" id="tabAnbCategorySub01">
# <div class="custom_scroll_wrap">
# <div class="category_view_area"> <a class="btn_arw_link" href="https://product.kyobobook.co.kr/"> <span class="text">국내도서 전체</span> </a>
# <div class="fold_box_wrap category">
# <div class="col_area">
# <ul class="fold_box_list">
# <li class="fold_box">
# <div class="fold_box_header"> <a href="https://product.kyobobook.co.kr/category/KOR/01"> 소설 </a> <button class="btn_fold" type="button"> <span class="hidden">컨텐츠 열기</span> </button>
# </div>
# <div class="fold_box_contents">
# <ul class="category_list">
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0101">한국소설</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0103">영미소설</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0105">일본소설</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0107">중국소설</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0109">러시아소설</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0111">프랑스소설</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0112">독일소설</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0115">북유럽소설</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0116">그외유럽소설</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0117">기타나라소설</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0118">청소년소설</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0121">고전소설/문학선</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0124">세계문학전집</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0126">라이트노벨</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0128">장르소설</a> </li>
# </ul>
# </div> </li>
# <li class="fold_box">
# <div class="fold_box_header"> <a href="https://product.kyobobook.co.kr/category/KOR/03"> 시/에세이 </a> <button class="btn_fold" type="button"> <span class="hidden">컨텐츠 열기</span> </button>
# </div>
# <div class="fold_box_contents">
# <ul class="category_list">
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0301">한국시</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0302">해외시</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0304">테마에세이</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0307">나라별 에세이</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0311">인물/자전적에세이</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0317">청소년 시/에세이</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0319">시/에세이문고</a> </li>
# </ul>
# </div> </li>
# <li class="fold_box">
# <div class="fold_box_header"> <a href="https://product.kyobobook.co.kr/category/KOR/05"> 인문 </a> <button class="btn_fold" type="button"> <span class="hidden">컨텐츠 열기</span> </button>
# </div>
# <div class="fold_box_contents">
# <ul class="category_list">
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0501">인문학일반</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0503">심리학</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0505">교육학</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0507">유아교육</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0509">특수교육</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0511">임용고시</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0513">철학</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0515">문학이론</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0517">한국문학론</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0519">영미문학론</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0520">중국문학론</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0521">세계문학론</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0523">언어학</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0525">독서/글쓰기</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0527">문헌정보학</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0529">역학/사주</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0532">대학교재</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0533">인문교양총서</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0535">인문고전총서</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0551">방송통신대교재</a> </li>
# </ul>
# </div> </li>
# <li class="fold_box">
# <div class="fold_box_header"> <a href="https://product.kyobobook.co.kr/category/KOR/07"> 가정/육아 </a> <button class="btn_fold" type="button"> <span class="hidden">컨텐츠 열기</span> </button>
# </div>
# <div class="fold_box_contents">
# <ul class="category_list">
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0701">결혼/가정</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0703">임신/출산</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0704">육아</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0705">자녀교육</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0707">살림의지혜</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0709">홈인테리어</a> </li>
# </ul>
# </div> </li>
# <li class="fold_box">
# <div class="fold_box_header"> <a href="https://product.kyobobook.co.kr/category/KOR/08"> 요리 </a> <button class="btn_fold" type="button"> <span class="hidden">컨텐츠 열기</span> </button>
# </div>
# <div class="fold_box_contents">
# <ul class="category_list">
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0801">요리일반</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0802">요리에세이</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0803">테마별요리</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0805">베이킹/간식</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0807">계절요리</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0809">재료별요리</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0811">나라별요리</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0813">생활요리</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0815">전문요리</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0817">와인/커피/음료</a> </li>
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0819">요리수험서</a> </li>
# </ul>
# </div> </li>
# <li class="fold_box">
# <div class="fold_box_header"> <a href="https://product.kyobobook.co.kr/category/KOR/09"> 건강 </a> <button class="btn_fold" type="button"> <span class="hidden">컨텐츠 열기</span> </button>
# </div>
# <div class="fold_box_contents">
# <ul class="category_list">
# <li class="category_item"> <a class="category_link" href="https://product.kyobobook.co.kr/category/KOR/0901">건강일반</a> </li>
# ...
#                                                 도전해봐요! :)
#                                             </div>
# </div>
# </div>
# <div class="reply_item">
# <div class="reply_header">
# <div class="user_info_box">
# <span class="info_item">ab******</span>
# <span class="info_item">
# <button class="btn_comment_util" type="button"><span class="text">수정</span></button>
# </span>
# <span class="gap"> | </span>
# <span class="info_item">
# <button class="btn_comment_util" type="button"><span class="text">삭제</span></button>
# </span>
# </div>
# </div>
# <div class="reply_contents">
# <div class="reply_text">
#                                                 기대가됩니다~
#                                             </div>
# </div>
# </div>
# </div>
# <!-- 댓글 5개 이상일 경우 노출 -->
# <!--<div class="auto_overflow_wrap">
#                                         <div class="auto_overflow_contents">
#                                             <div class="auto_overflow_inner">
#                                                 <div class="reply_list">
#                                                     <div class="reply_item">
#                                                         <div class="reply_header">
#                                                             <div class="user_info_box">
#                                                                 <span class="info_item">ab******</span>
#                                                                 <span class="gap"> | </span>
#                                                                 <span class="info_item">2021.07.11</span>
#                                                                 <span class="gap"> | </span>
#                                                                 <span class="info_item">
#                                                         <button type="button" class="btn_comment_util"><span class="text">신고</span></button>
#                                                     </span>
#                                                             </div>
#                                                         </div>
#                                                         <div class="reply_contents">
#                                                             <div class="reply_text">
#                                                                 작년까지만 해도 주식은 커녕 재테크에 관해 아무것도 모르다가 구매했어요! 저도 공부하고 싶어서 구매했어요~ 다같이 완독 도전해봐요! :)
#                                                             </div>
#                                                         </div>
#                                                     </div>
#                                                     <div class="reply_item">
#                                                         <div class="reply_header">
#                                                             <div class="user_info_box">
#                                                                 <span class="info_item">ab******</span>
#                                                                 <span class="gap"> | </span>
#                                                                 <span class="info_item">2021.07.11</span>
#                                                                 <span class="gap"> | </span>
#                                                                 <span class="info_item">
#                                                         <button type="button" class="btn_comment_util"><span class="text">신고</span></button>
#                                                     </span>
#                                                             </div>
#                                                         </div>
#                                                         <div class="reply_contents">
#                                                             <div class="reply_text">
#                                                                 기대가됩니다~
#                                                             </div>
#                                                         </div>
#                                                     </div>
#                                                     <div class="reply_item">
#                                                         <div class="reply_header">
#                                                             <div class="user_info_box">
#                                                                 <span class="info_item">ab******</span>
#                                                                 <span class="gap"> | </span>
#                                                                 <span class="info_item">2021.07.11</span>
#                                                                 <span class="gap"> | </span>
#                                                                 <span class="info_item">
#                                                         <button type="button" class="btn_comment_util"><span class="text">신고</span></button>
#                                                     </span>
#                                                             </div>
#                                                         </div>
#                                                         <div class="reply_contents">
#                                                             <div class="reply_text">
#                                                                 기대가됩니다~
#                                                             </div>
#                                                         </div>
#                                                     </div>
#                                                     <div class="reply_item">
#                                                         <div class="reply_header">
#                                                             <div class="user_info_box">
#                                                                 <span class="info_item">ab******</span>
#                                                                 <span class="gap"> | </span>
#                                                                 <span class="info_item">2021.07.11</span>
#                                                                 <span class="gap"> | </span>
#                                                                 <span class="info_item">
#                                                         <button type="button" class="btn_comment_util"><span class="text">신고</span></button>
#                                                     </span>
#                                                             </div>
#                                                         </div>
#                                                         <div class="reply_contents">
#                                                             <div class="reply_text">
#                                                                 기대가됩니다~
#                                                             </div>
#                                                         </div>
#                                                     </div>
#                                                     <div class="reply_item">
#                                                         <div class="reply_header">
#                                                             <div class="user_info_box">
#                                                                 <span class="info_item">ab******</span>
#                                                                 <span class="gap"> | </span>
#                                                                 <span class="info_item">2021.07.11</span>
#                                                                 <span class="gap"> | </span>
#                                                                 <span class="info_item">
#                                                         <button type="button" class="btn_comment_util"><span class="text">신고</span></button>
#                                                     </span>
#                                                             </div>
#                                                         </div>
#                                                         <div class="reply_contents">
#                                                             <div class="reply_text">
#                                                                 기대가됩니다~
#                                                             </div>
#                                                         </div>
#                                                     </div>
#                                                 </div>
#                                             </div>
#                                         </div>
#                                         <div class="auto_overflow_footer">
#                                             <button type="button" class="btn_more_body" data-btn-toggle=""><span class="text">답글 더보기</span><span class="ico_arw"></span></button>
#                                         </div>
#                                     </div>-->
# <!-- //댓글 5개 이상일 경우 노출 -->
# </div>
# <!-- //댓글 리스트 -->
# </div>
# <!-- //답글 -->
# </div>
# </div>
# </div>
# <!-- //수정 211217 리뷰영역 구조 재작업 -->
# </div>
# </div>
# <!-- //dialog_contents -->
# </div>
# <!-- //한달 후 리뷰_포토 -->
# <div class="dialog_wrap has_btn" id="rdoReport">
# <button class="btn_dialog_close" data-dialog-close="" type="button"><span class="ico_dialog_close"></span><span class="hidden">닫기</span></button>
# <!-- dialog_header -->
# <div class="dialog_header">
# <div class="dialog_title">신고</div>
# </div>
# <!-- //dialog_header -->
# <!-- dialog_contents -->
# <div class="dialog_contents">
# <div class="custom_scroll_wrap">
# <p class="info_text font_size_sm">신고 사유를 선택해주세요.<br/>신고 내용은 이용약관 및 정책에 의해 처리됩니다.</p>
# <div class="round_gray_box type_sub">
# <div class="box_info_inner">
# <!-- chk_col_list -->
# <ul class="chk_col_list toggle_textarea_list">
# <li class="chk_col_item">
# <!-- form_rdo -->
# <span class="form_rdo">
# <input checked="" id="rdoReport01" name="rdoReport" type="radio"/>
# <label for="rdoReport01">비방, 명예훼손, 욕설, 혐오발언</label>
# </span>
# <!-- //form_rdo -->
# </li>
# <li class="chk_col_item">
# <!-- form_rdo -->
# <span class="form_rdo">
# <input id="rdoReport02" name="rdoReport" type="radio"/>
# <label for="rdoReport02">홍보, 영리목적</label>
# </span>
# <!-- //form_rdo -->
# </li>
# <li class="chk_col_item">
# <!-- form_rdo -->
# <span class="form_rdo">
# <input id="rdoReport03" name="rdoReport" type="radio"/>
# <label for="rdoReport03">음란, 유해, 불법정보</label>
# </span>
# <!-- //form_rdo -->
# </li>
# <li class="chk_col_item">
# <!-- form_rdo -->
# <span class="form_rdo">
# <input id="rdoReport04" name="rdoReport" type="radio"/>
# <label for="rdoReport04">도서와 무관한 내용</label>
# </span>
# <!-- //form_rdo -->
# </li>
# <li class="chk_col_item">
# <!-- form_rdo -->
# <span class="form_rdo">
# <input id="rdoReport05" name="rdoReport" type="radio"/>
# <label for="rdoReport05">도배 및 내용이 없는 리뷰</label>
# </span>
# <!-- //form_rdo -->
# </li>
# <li class="chk_col_item">
# <!-- form_rdo -->
# <span class="form_rdo">
# <input id="rdoReport06" name="rdoReport" type="radio"/>
# <label for="rdoReport06">기타</label>
# </span>
# <!-- //form_rdo -->
# <!-- byte_check_wrap -->
# <!-- DESC : 신고하기 항목 - '기타'의 textarea는 기본 disabled 상태 (다른 항목 선택 시 활성화처리는 스크립트 적용되어 있음) -->
# <div class="byte_check_wrap">
# <textarea class="form_textarea" disabled="" placeholder="신고 내용을 입력해주세요." style="height: 55px;" title="신고 내용을 입력해주세요"></textarea>
# <div class="byte_check_footer">
# <div class="byte_check">
# <span class="count">12</span>
# <span class="total">300</span>
# </div>
# </div>
# </div>
# <!-- //byte_check_wrap -->
# </li>
# </ul>
# <!-- //chk_col_list -->
# </div>
# </div>
# <p class="bul_item_asterisk">허위 신고일 경우, 신고자의 서비스 활동이 제한될 수 있으니 유의하시어<br/>
#                 신중하게 신고해주세요.</p>
# </div>
# </div>
# <!-- //dialog_contents -->
# <!-- dialog_footer -->
# <div class="dialog_footer">
# <button class="btn_md btn_primary" data-dialog-close="" type="button"><span class="text">신고</span></button>
# </div>
# <!-- //dialog_footer -->
# </div>
# <div class="dialog_wrap no_title_line" data-class="dialog_lg dialog_series_list" id="popSeriesList">
# <button class="btn_dialog_close" data-dialog-close="" type="button"><span class="ico_dialog_close"></span><span class="hidden">닫기</span></button>
# <div class="dialog_header">
# <div class="dialog_title"></div>
# </div>
# <div class="dialog_contents">
# <div class="custom_scroll_wrap">
# <div class="list_result_wrap">
# <span class="form_chk">
# <input id="chkAllSeriesChk" type="checkbox"/>
# <label for="chkAllSeriesChk">전체선택</label>
# </span>
# <div class="right_area">
# <div class="item_group">
# <button class="btn_wish size_sm" data-kbbfn="wish-item-list" data-kbbfn-allckeck="#popSeriesList #chkAllSeriesChk" data-kbbfn-list="#popSeriesList .prod_list" data-kbbfn-myrcode="001" data-kbbfn-nbopcode="001" type="button"><span class="ico_wish"></span><span class="hidden">찜하기</span></button>
# <button class="btn_sm btn_line_gray" data-kbbfn="cart-item" data-kbbfn-cartallcheck="#popSeriesList #chkAllSeriesChk" data-kbbfn-cartlist="#popSeriesList .prod_list" type="button"><span class="ico_cart"></span><span class="text">장바구니 담기</span></button>
# </div>
# </div>
# </div>
# <div class="switch_prod_wrap view_type_list">
# <ul class="prod_list">
# </ul>
# <div class="pagination">
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="dialog_wrap" data-class="dialog_sm" id="popBookSizeInfo">
# <button class="btn_dialog_close" data-dialog-close="" type="button"><span class="ico_dialog_close"></span><span class="hidden">닫기</span></button>
# <div class="dialog_header">
# <h1 class="dialog_title">판형알림</h1>
# </div>
# <div class="dialog_contents">
# <div class="custom_scroll_wrap">
# <div class="book_size_info_box">
# <ul class="bul_list">
# <li class="bul_item_dot font_size_xxs">A3 [297×420mm]</li>
# <li class="bul_item_dot font_size_xxs">A4 [210×297mm]</li>
# <li class="bul_item_dot font_size_xxs">A5 [148×210mm]</li>
# <li class="bul_item_dot font_size_xxs">A6 [105×148mm]</li>
# <li class="bul_item_dot font_size_xxs">B4 [257×364mm]</li>
# <li class="bul_item_dot font_size_xxs">B5 [182×257mm]</li>
# <li class="bul_item_dot font_size_xxs">B6 [128×182mm]</li>
# <li class="bul_item_dot font_size_xxs">8C [8절]</li>
# <li class="bul_item_dot font_size_xxs">기타 [가로×세로]</li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <!-- 버거메뉴 -->
# <script data-name="jquery-ui" src="https://contents.kyobobook.co.kr/resources/fo/vendors/jquery-ui-1.12.1/jquery-ui.min.js"></script>
# <script src="https://contents.kyobobook.co.kr/resources/fo/vendors/jquery-ui-1.12.1/jquery.ui.spinner.js"></script>
# <script data-name="ResizeSensor" src="https://contents.kyobobook.co.kr/resources/fo/vendors/css-element-queries/ResizeSensor.js"></script>
# <script data-name="awesomplete" src="https://contents.kyobobook.co.kr/resources/fo/vendors/awesomplete/awesomplete.min.js"></script>
# <script data-name="star-rating" src="https://contents.kyobobook.co.kr/resources/fo/vendors/star-rating/js/star-rating.min.js"></script>
# <script src="https://contents.kyobobook.co.kr/resources/fo/vendors/star-rating/js/locales/ko.js"></script>
# <script src="https://contents.kyobobook.co.kr/resources/fo/vendors/star-rating/themes/krajee-gly/theme.min.js"></script>
# <script data-name="scrollPosStyler" src="https://contents.kyobobook.co.kr/resources/fo/vendors/scrollpos-styler/scrollPosStyler.min.js"></script>
# <script data-name="blurify" src="https://contents.kyobobook.co.kr/resources/fo/vendors/blurify-master/blurify.min.js"></script>
# <script data-name="masonry" src="https://contents.kyobobook.co.kr/resources/fo/vendors/masonry/masonry.pkgd.min.js"></script>
# <script data-name="swiper" src="https://contents.kyobobook.co.kr/resources/fo/vendors/swiper/v4/swiper.min.js"></script>
# <script data-name="svgxuse" src="https://contents.kyobobook.co.kr/resources/fo/vendors/svgxuse/svgxuse.js"></script>
# <script data-name="simplebar" src="https://contents.kyobobook.co.kr/resources/fo/vendors/simplebar/5.3.3/simplebar.min.js"></script>
# <script>KbbJS.import('kbb-cm-script')</script>
# <script src="/assets/js/vars.js"></script>
# <script src="/assets/js/detail.js"></script>
# </body>
# </html>

# %%
import requests
import bs4
# url = "http://www.kyobobook.co.kr/indexKor.laf?mallGb=KOR&orderClick=sg"
# html = requests.get(url).content
# soup = bs4.BeautifulSoup(html, "lxml")
# for i in soup.find_all("ul", class_="category")[0].find_all("a", href=True):
#     print(i)
#     print()
# soup = bs4.BeautifulSoup(bytes(list(soup.find_all("ul", class_="category"))[0]), "lxml")
# print(soup)

subject_list = {
    "01":"소설", "03":"시/에세이", "05":"인문", "13":"경제/경영", "15":"자기계발",
    "19":"역사/문화", "21":"종교", "17":"정치사회", "23":"예술/대중문화",
    "29":"과학", "26":"기술/공학", "33":"컴퓨터/IT"
}

success = [200,299]

for i in subject_list:
    for j in range(1,50,2):
        num = int(i)*100 + j
        url = f"http://www.kyobobook.co.kr/categoryRenewal/categoryMain.laf?linkClass={num:04d}&mallGb=KOR&orderClick=sga"
        data = requests.get(url)
        if success[0]<=data.status_code and data.status_code<=success[1]:
            soup = bs4.BeautifulSoup(data.content, "lxml")
            sublist = soup.find_all("p",class_="location")
            # print(len(sublist))
            if len(sublist) > 2:
                subject = sublist[2].span.a.contents[0].replace('\r', '').replace('\t', '').replace('\n', '')
                print(subject)
                print(len(subject))
                print("="*100)
        else:
            pass
    break
# Out:
# 한국소설
# 4
# ====================================================================================================
# 영미소설
# 4
# ====================================================================================================
# 일본소설
# 4
# ====================================================================================================
# 중국소설
# 4
# ====================================================================================================
# 러시아소설
# 5
# ====================================================================================================
# 프랑스소설
# 5
# ====================================================================================================
# 북유럽소설
# 5
# ====================================================================================================
# 기타나라소설
# 6
# ====================================================================================================
# 고전소설/문학선
# 8
# ====================================================================================================

# %%
import numpy as np
x = [1,2,3]
y = [2,3,5]
cost = np.linalg.norm(2-4)
print(cost)
cost = abs(2-4)
print(cost)
# Out:
# 2.0
# 2

# %%
with open("./test.txt", "r") as f:
    data = f.read()
    print(data)
# Out:
# 132 24 1 15
# 42 2 35 123
# 1234 43 23 4

# %%
with open("./test.txt", "r") as f:
    data = f.readline()
    print(data)
    data = f.readline()
    print(data)
# Out:
# 132 24 1 15
#
# 42 2 35 123

# %%
with open("./test.txt", "r") as f:
    data = f.readlines()
    print(data)
# Out:
# ['132 24 1 15\n', '42 2 35 123\n', '1234 43 23 4']
